# %% [markdown]
# Lucas Bouchard
#
# # NCAA Tournament Project: Web Scraping, graphing, and networking

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#import seaborn as sb
import requests
import networkx as nx
from bs4 import BeautifulSoup, NavigableString

# %% [markdown]
# # Getting the data

# %% [markdown]
# Tournament page data

# %%
raw = requests.get('http://www.sports-reference.com/cbb/postseason/2017-ncaa.html').text
soup = BeautifulSoup(raw, 'lxml')

# %% [markdown]
# Parsing out all the divisions.

# %%
east_soup = soup.find_all('div',{'id':'east'})
east_soup[0]
midwest_soup = soup.find_all('div',{'id':'midwest'})
south_soup = soup.find_all('div',{'id':'south'})
west_soup = soup.find_all('div',{'id':'west'})

# %%
east_soup[0].find_all('a')[5].text
# Out:
# 'Wisconsin'

# %%
teams_href_list = list()
for link in east_soup[0].find_all('a'):
    if len(link.text) > 0:
        teams_href_list.append(link['href'])

teams_href_list
# Out:
# ['/cbb/schools/villanova/2017.html',
#  '/cbb/boxscores/2017-03-16-villanova.html',
#  '/cbb/schools/mount-st-marys/2017.html',
#  '/cbb/boxscores/2017-03-16-villanova.html',
#  '/cbb/boxscores/2017-03-16-villanova.html',
#  '/cbb/schools/wisconsin/2017.html',
#  '/cbb/boxscores/2017-03-16-wisconsin.html',
#  '/cbb/schools/virginia-tech/2017.html',
#  '/cbb/boxscores/2017-03-16-wisconsin.html',
#  '/cbb/boxscores/2017-03-16-wisconsin.html',
#  '/cbb/schools/virginia/2017.html',
#  '/cbb/boxscores/2017-03-16-virginia.html',
#  '/cbb/schools/north-carolina-wilmington/2017.html',
#  '/cbb/boxscores/2017-03-16-virginia.html',
#  '/cbb/boxscores/2017-03-16-virginia.html',
#  '/cbb/schools/florida/2017.html',
#  '/cbb/boxscores/2017-03-16-florida.html',
#  '/cbb/schools/east-tennessee-state/2017.html',
#  '/cbb/boxscores/2017-03-16-florida.html',
#  '/cbb/boxscores/2017-03-16-florida.html',
#  '/cbb/schools/southern-methodist/2017.html',
#  '/cbb/boxscores/2017-03-17-southern-methodist.html',
#  '/cbb/schools/southern-california/2017.html',
#  '/cbb/boxscores/2017-03-17-southern-methodist.html',
#  '/cbb/boxscores/2017-03-17-southern-methodist.html',
#  '/cbb/schools/baylor/2017.html',
#  '/cbb/boxscores/2017-03-17-baylor.html',
#  '/cbb/schools/new-mexico-state/2017.html',
#  '/cbb/boxscores/2017-03-17-baylor.html',
#  '/cbb/boxscores/2017-03-17-baylor.html',
#  '/cbb/schools/south-carolina/2017.html',
#  '/cbb/boxscores/2017-03-17-south-carolina.html',
#  '/cbb/schools/marquette/2017.html',
#  '/cbb/boxscores/2017-03-17-south-carolina.html',
#  '/cbb/boxscores/2017-03-17-south-carolina.html',
#  '/cbb/schools/duke/2017.html',
#  '/cbb/boxscores/2017-03-17-duke.html',
#  '/cbb/schools/troy/2017.html',
#  '/cbb/boxscores/2017-03-17-duke.html',
#  '/cbb/boxscores/2017-03-17-duke.html',
#  '/cbb/schools/villanova/2017.html',
#  '/cbb/boxscores/2017-03-18-villanova.html',
#  '/cbb/schools/wisconsin/2017.html',
#  '/cbb/boxscores/2017-03-18-villanova.html',
#  '/cbb/boxscores/2017-03-18-villanova.html',
#  '/cbb/schools/virginia/2017.html',
#  '/cbb/boxscores/2017-03-18-florida.html',
#  '/cbb/schools/florida/2017.html',
#  '/cbb/boxscores/2017-03-18-florida.html',
#  '/cbb/boxscores/2017-03-18-florida.html',
#  '/cbb/schools/southern-california/2017.html',
#  '/cbb/boxscores/2017-03-19-baylor.html',
#  '/cbb/schools/baylor/2017.html',
#  '/cbb/boxscores/2017-03-19-baylor.html',
#  '/cbb/boxscores/2017-03-19-baylor.html',
#  '/cbb/schools/south-carolina/2017.html',
#  '/cbb/boxscores/2017-03-19-duke.html',
#  '/cbb/schools/duke/2017.html',
#  '/cbb/boxscores/2017-03-19-duke.html',
#  '/cbb/boxscores/2017-03-19-duke.html',
#  '/cbb/schools/wisconsin/2017.html',
#  '/cbb/boxscores/2017-03-24-florida.html',
#  '/cbb/schools/florida/2017.html',
#  '/cbb/boxscores/2017-03-24-florida.html',
#  '/cbb/boxscores/2017-03-24-florida.html',
#  '/cbb/schools/baylor/2017.html',
#  '/cbb/boxscores/2017-03-24-baylor.html',
#  '/cbb/schools/south-carolina/2017.html',
#  '/cbb/boxscores/2017-03-24-baylor.html',
#  '/cbb/boxscores/2017-03-24-baylor.html',
#  '/cbb/schools/florida/2017.html',
#  '/cbb/boxscores/2017-03-26-florida.html',
#  '/cbb/schools/south-carolina/2017.html',
#  '/cbb/boxscores/2017-03-26-florida.html',
#  '/cbb/boxscores/2017-03-26-florida.html',
#  '/cbb/schools/south-carolina/2017.html']

# %% [markdown]
# # Parsing the HTML to get all the teams in each division

# %%
def get_teams(division_soup):
    teams_href_list = list()
    for link in division_soup[0].find_all('a'):
        if len(link.text) > 0 and 'schools' in link['href']:
            teams_href_list.append(link)
            
    return teams_href_list

# %% [markdown]
# # Using 'soup' to put each division in list to see all teams in 2017 tournament.

# %%
east_teams_2017 = get_teams(east_soup)
midwest_teams_2017 = get_teams(midwest_soup)
south_teams_2017 = get_teams(south_soup)
west_teams_2017 = get_teams(west_soup)
teams_2017 = east_teams_2017 + midwest_teams_2017 + south_teams_2017 + west_teams_2017
len(teams_2017)
# Out:
# 124

# %%
cleaned_teams = list()
for team in teams_2017:
    if team not in cleaned_teams:
        cleaned_teams.append(team)
len(cleaned_teams)
# Out:
# 64

# %% [markdown]
# # Looping through 'teams_2017' to make 'tournament_teams' by applying the '.text' to each element which extracts the cleaned name of the team and appends it to new list.

# %%
tournament_teams = list()
for team in teams_2017:
    if team.text not in tournament_teams:
        tournament_teams.append(team.text)
tournament_teams
# Out:
# ['Villanova',
#  "Mount St. Mary's",
#  'Wisconsin',
#  'Virginia Tech',
#  'Virginia',
#  'North Carolina-Wilmington',
#  'Florida',
#  'ETSU',
#  'SMU',
#  'USC',
#  'Baylor',
#  'New Mexico State',
#  'South Carolina',
#  'Marquette',
#  'Duke',
#  'Troy',
#  'Kansas',
#  'UC-Davis',
#  'Miami (FL)',
#  'Michigan State',
#  'Iowa State',
#  'Nevada',
#  'Purdue',
#  'Vermont',
#  'Creighton',
#  'Rhode Island',
#  'Oregon',
#  'Iona',
#  'Michigan',
#  'Oklahoma State',
#  'Louisville',
#  'Jacksonville State',
#  'UNC',
#  'Texas Southern',
#  'Arkansas',
#  'Seton Hall',
#  'Minnesota',
#  'Middle Tennessee',
#  'Butler',
#  'Winthrop',
#  'Cincinnati',
#  'Kansas State',
#  'UCLA',
#  'Kent State',
#  'Dayton',
#  'Wichita State',
#  'Kentucky',
#  'Northern Kentucky',
#  'Gonzaga',
#  'South Dakota State',
#  'Northwestern',
#  'Vanderbilt',
#  'Notre Dame',
#  'Princeton',
#  'West Virginia',
#  'Bucknell',
#  'Maryland',
#  'Xavier',
#  'Florida State',
#  'Florida Gulf Coast',
#  "Saint Mary's (CA)",
#  'VCU',
#  'Arizona',
#  'North Dakota']

# %% [markdown]
# # Getting the `href` out of a single team in `teams_2017`.

# %%
teams_2017[0]['href']
# Out:
# '/cbb/schools/villanova/2017.html'

# %% [markdown]
# # Using the `replace` string function to update the `href' so we can get 2017-schedual

# %%
'http://www.sports-reference.com' + teams_2017[0]['href'].replace('2017','2017-schedule')
# Out:
# 'http://www.sports-reference.com/cbb/schools/villanova/2017-schedule.html'

# %% [markdown]
# # Making a `_url` variable that combines the domain ("http://www.sports-reference.com/") and the `href` updated to contain "2017-schedule.html". Then used requests' `get` and `text` methods to get the raw HTML, saving it as `team_raw.` Madee `team_soup` out of `team_raw,` and then found specific table containing the schedule

# %%
raw = requests.get('http://www.sports-reference.com/cbb/schools/virginia/2017-schedule.html').text
soup = BeautifulSoup(raw, 'lxml')

schedule_table = soup.find_all('table',{'id':'schedule','class':"sortable stats_table"})
row = schedule_table[0].find_all('tr')[1]
row
#.find_all('td')
# Out:
# <tr><th class="right " data-stat="g" scope="row">1</th><td class="left " csk="2016-11-11" data-stat="date_game"><a href="/cbb/boxscores/2016-11-11-north-carolina-greensboro.html">Fri, Nov 11, 2016</a></td><td class="left " data-stat="time_game">7:00 pm/est</td><td class="left " data-stat="network"></td><td class="left " data-stat="game_type">REG</td><td class="left " data-stat="game_location">@</td><td class="left " data-stat="opp_name"><a href="/cbb/schools/north-carolina-greensboro/2017.html">North Carolina-Greensboro</a></td><td class="left " data-stat="conf_abbr"><a href="/cbb/conferences/southern/2017.html" title="Southern Conference">Southern</a></td><td class="left " data-stat="game_result">W</td><td class="right " data-stat="pts">76</td><td class="right " data-stat="opp_pts">51</td><td class="center " data-stat="overtimes"></td><td class="right " data-stat="wins">1</td><td class="right " data-stat="losses">0</td><td class="left " csk="1" data-stat="game_streak">W 1</td><td class="left " data-stat="arena">Greensboro Coliseum</td></tr>

# %%
schedule_table[0].find_all('td',{'data-stat':'date_game'})[0].text
# Out:
# 'Fri, Nov 11, 2016'

# %% [markdown]
# # Parsing the `schedule_table`

# %%
schedule_table[0].find_all('td',{'data-stat':'opp_name'})
# Out:
# [<td class="left " data-stat="opp_name"><a href="/cbb/schools/north-carolina-greensboro/2017.html">North Carolina-Greensboro</a></td>,
#  <td class="left " data-stat="opp_name"><a href="/cbb/schools/st-francis-ny/2017.html">St. Francis (NY)</a></td>,
#  <td class="left " data-stat="opp_name"><a href="/cbb/schools/yale/2017.html">Yale</a></td>,
#  <td class="left " data-stat="opp_name"><a href="/cbb/schools/grambling/2017.html">Grambling</a></td>,
#  <td class="left " data-stat="opp_name"><a href="/cbb/schools/iowa/2017.html">Iowa</a></td>,
#  <td class="left " data-stat="opp_name"><a href="/cbb/schools/providence/2017.html">Providence</a></td>,
#  <td class="left " data-stat="opp_name"><a href="/cbb/schools/ohio-state/2017.html">Ohio State</a></td>,
#  <td class="left " data-stat="opp_name"><a href="/cbb/schools/west-virginia/2017.html">West Virginia</a> <span class="note">(25)</span></td>,
#  <td class="left " data-stat="opp_name"><a href="/cbb/schools/east-carolina/2017.html">East Carolina</a></td>,
#  <td class="left " data-stat="opp_name"><a href="/cbb/schools/robert-morris/2017.html">Robert Morris</a></td>,
#  <td class="left " data-stat="opp_name"><a href="/cbb/schools/california/2017.html">University of California</a></td>,
#  <td class="left " data-stat="opp_name"><a href="/cbb/schools/louisville/2017.html">Louisville</a> <span class="note">(6)</span></td>,
#  <td class="left " data-stat="opp_name"><a href="/cbb/schools/florida-state/2017.html">Florida State</a> <span class="note">(20)</span></td>,
#  <td class="left " data-stat="opp_name"><a href="/cbb/schools/pittsburgh/2017.html">Pittsburgh</a></td>,
#  <td class="left " data-stat="opp_name"><a href="/cbb/schools/wake-forest/2017.html">Wake Forest</a></td>,
#  <td class="left " data-stat="opp_name"><a href="/cbb/schools/clemson/2017.html">Clemson</a></td>,
#  <td class="left " data-stat="opp_name"><a href="/cbb/schools/boston-college/2017.html">Boston College</a></td>,
#  <td class="left " data-stat="opp_name"><a href="/cbb/schools/georgia-tech/2017.html">Georgia Tech</a></td>,
#  <td class="left " data-stat="opp_name"><a href="/cbb/schools/notre-dame/2017.html">Notre Dame</a> <span class="note">(14)</span></td>,
#  <td class="left " data-stat="opp_name"><a href="/cbb/schools/villanova/2017.html">Villanova</a> <span class="note">(1)</span></td>,
#  <td class="left " data-stat="opp_name"><a href="/cbb/schools/virginia-tech/2017.html">Virginia Tech</a></td>,
#  <td class="left " data-stat="opp_name"><a href="/cbb/schools/syracuse/2017.html">Syracuse</a></td>,
#  <td class="left " data-stat="opp_name"><a href="/cbb/schools/louisville/2017.html">Louisville</a> <span class="note">(4)</span></td>,
#  <td class="left " data-stat="opp_name"><a href="/cbb/schools/virginia-tech/2017.html">Virginia Tech</a></td>,
#  <td class="left " data-stat="opp_name"><a href="/cbb/schools/duke/2017.html">Duke</a> <span class="note">(12)</span></td>,
#  <td class="left " data-stat="opp_name"><a href="/cbb/schools/north-carolina/2017.html">North Carolina</a> <span class="note">(10)</span></td>,
#  <td class="left " data-stat="opp_name"><a href="/cbb/schools/miami-fl/2017.html">Miami (FL)</a></td>,
#  <td class="left " data-stat="opp_name"><a href="/cbb/schools/north-carolina-state/2017.html">North Carolina State</a></td>,
#  <td class="left " data-stat="opp_name"><a href="/cbb/schools/north-carolina/2017.html">North Carolina</a> <span class="note">(5)</span></td>,
#  <td class="left " data-stat="opp_name"><a href="/cbb/schools/pittsburgh/2017.html">Pittsburgh</a></td>,
#  <td class="left " data-stat="opp_name"><a href="/cbb/schools/pittsburgh/2017.html">Pittsburgh</a></td>,
#  <td class="left " data-stat="opp_name"><a href="/cbb/schools/notre-dame/2017.html">Notre Dame</a> <span class="note">(22)</span></td>,
#  <td class="left " data-stat="opp_name"><a href="/cbb/schools/north-carolina-wilmington/2017.html">North Carolina-Wilmington</a></td>,
#  <td class="left " data-stat="opp_name"><a href="/cbb/schools/florida/2017.html">Florida</a> <span class="note">(20)</span></td>]

# %% [markdown]
# # Parsing out the opponents and saving list of values as `opponents`.

# %%
opponents = list()
for opp in schedule_table[0].find_all('td',{'data-stat':'opp_name'}):
    opponents.append(opp.text)
opponents
# Out:
# ['North Carolina-Greensboro',
#  'St. Francis (NY)',
#  'Yale',
#  'Grambling',
#  'Iowa',
#  'Providence',
#  'Ohio State',
#  'West Virginia\xa0(25)',
#  'East Carolina',
#  'Robert Morris',
#  'University of California',
#  'Louisville\xa0(6)',
#  'Florida State\xa0(20)',
#  'Pittsburgh',
#  'Wake Forest',
#  'Clemson',
#  'Boston College',
#  'Georgia Tech',
#  'Notre Dame\xa0(14)',
#  'Villanova\xa0(1)',
#  'Virginia Tech',
#  'Syracuse',
#  'Louisville\xa0(4)',
#  'Virginia Tech',
#  'Duke\xa0(12)',
#  'North Carolina\xa0(10)',
#  'Miami (FL)',
#  'North Carolina State',
#  'North Carolina\xa0(5)',
#  'Pittsburgh',
#  'Pittsburgh',
#  'Notre Dame\xa0(22)',
#  'North Carolina-Wilmington',
#  'Florida\xa0(20)']

# %% [markdown]
# # Parsing out the results and saving list of values as `results`.

# %%
results = list()
for sult in schedule_table[0].find_all('td',{'data-stat':'game_result'}):
    results.append(sult.text)
results
# Out:
# ['W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'L',
#  'W',
#  'W',
#  'W',
#  'W',
#  'L',
#  'L',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'L',
#  'W',
#  'L',
#  'W',
#  'L',
#  'L',
#  'L',
#  'L',
#  'W',
#  'W',
#  'W',
#  'W',
#  'L',
#  'W',
#  'L']

# %% [markdown]
# # Parsing out the team score and saving list of values as `team_scores`.

# %%
team_score = list()
for point in schedule_table[0].find_all('td',{'data-stat':'pts'}):
    team_score.append(point.text)
team_score
# Out:
# ['76',
#  '72',
#  '62',
#  '90',
#  '74',
#  '63',
#  '63',
#  '57',
#  '76',
#  '79',
#  '56',
#  '61',
#  '58',
#  '76',
#  '79',
#  '77',
#  '71',
#  '62',
#  '71',
#  '59',
#  '71',
#  '62',
#  '71',
#  '78',
#  '55',
#  '41',
#  '48',
#  '70',
#  '53',
#  '67',
#  '75',
#  '58',
#  '76',
#  '39']

# %% [markdown]
# # Parsing out the opponent's score and saving list of values as `opp_scores`.

# %%
opp_score = list()
for point in schedule_table[0].find_all('td',{'data-stat':'opp_pts'}):
    opp_score.append(point.text)
opp_score
# Out:
# ['51',
#  '32',
#  '38',
#  '34',
#  '41',
#  '52',
#  '61',
#  '66',
#  '53',
#  '39',
#  '52',
#  '53',
#  '60',
#  '88',
#  '62',
#  '73',
#  '54',
#  '49',
#  '54',
#  '61',
#  '48',
#  '66',
#  '55',
#  '80',
#  '65',
#  '65',
#  '54',
#  '55',
#  '43',
#  '42',
#  '63',
#  '71',
#  '71',
#  '65']

# %%
list1 = ['a','b','c']
list2 = [0,1,2]
list3 = ['alpha','beta','gamma']

zip(list1,list2,list3)

# %%
list(zip(list1,list2,list3))
# Out:
# [('a', 0, 'alpha'), ('b', 1, 'beta'), ('c', 2, 'gamma')]

# %%
list1 = opponents
list2 = results
list3 = team_score
list4 = opp_score

team_results=list(zip(list1,list2,list3,list4))
team_results
# Out:
# [('North Carolina-Greensboro', 'W', '76', '51'),
#  ('St. Francis (NY)', 'W', '72', '32'),
#  ('Yale', 'W', '62', '38'),
#  ('Grambling', 'W', '90', '34'),
#  ('Iowa', 'W', '74', '41'),
#  ('Providence', 'W', '63', '52'),
#  ('Ohio State', 'W', '63', '61'),
#  ('West Virginia\xa0(25)', 'L', '57', '66'),
#  ('East Carolina', 'W', '76', '53'),
#  ('Robert Morris', 'W', '79', '39'),
#  ('University of California', 'W', '56', '52'),
#  ('Louisville\xa0(6)', 'W', '61', '53'),
#  ('Florida State\xa0(20)', 'L', '58', '60'),
#  ('Pittsburgh', 'L', '76', '88'),
#  ('Wake Forest', 'W', '79', '62'),
#  ('Clemson', 'W', '77', '73'),
#  ('Boston College', 'W', '71', '54'),
#  ('Georgia Tech', 'W', '62', '49'),
#  ('Notre Dame\xa0(14)', 'W', '71', '54'),
#  ('Villanova\xa0(1)', 'L', '59', '61'),
#  ('Virginia Tech', 'W', '71', '48'),
#  ('Syracuse', 'L', '62', '66'),
#  ('Louisville\xa0(4)', 'W', '71', '55'),
#  ('Virginia Tech', 'L', '78', '80'),
#  ('Duke\xa0(12)', 'L', '55', '65'),
#  ('North Carolina\xa0(10)', 'L', '41', '65'),
#  ('Miami (FL)', 'L', '48', '54'),
#  ('North Carolina State', 'W', '70', '55'),
#  ('North Carolina\xa0(5)', 'W', '53', '43'),
#  ('Pittsburgh', 'W', '67', '42'),
#  ('Pittsburgh', 'W', '75', '63'),
#  ('Notre Dame\xa0(22)', 'L', '58', '71'),
#  ('North Carolina-Wilmington', 'W', '76', '71'),
#  ('Florida\xa0(20)', 'L', '39', '65')]

# %% [markdown]
# # Crawling all of the teams' tables

# %% [markdown]
# Here I create a loop that goes through each team in `teams_2017` and does all of the steps above in each pass.
#
# 0. Before the loop starts, has an empty list `all_results`
# 1. Checks to make sure the `team.text` isn't empty, skips urls that point to "tbd", or handles index position errors from pages with empty tables.
# 2. Takes the team object the url with the `href` replacement
# 3. Uses requests' `get` and `text` methods to get the raw HTML
# 4. Turns the raw HTML into Soup
# 5. Finds the table
# 6. Finds the dates, opponents, results, team score, and opponent scores
# 7. Zips them all together into `team_results`
# 8. For each result in `team_results` appends it to `all_results`

# %%
len(teams_2017)
cleaned_teams[0]['href'].replace('2017.html' , '2017_schedule.html')
# Out:
# '/cbb/schools/villanova/2017_schedule.html'

# %%
all_teams = list()
for team in cleaned_teams:
    url = 'http://www.sports-reference.com' + team['href'].replace('2017.html','2017-schedule.html')
    raw = requests.get(url).text
    soup = BeautifulSoup(raw,'lxml')
    schedule_table = soup.find_all('table',{'id':'schedule','class':'sortable stats_table'})
    all_results = list()
    all_results1 = list()
    result = list()
    all_results3 = list()
    all_results4 = list()
    for opp in schedule_table[0].find_all('td',{'data-stat':'date_game'}):
        all_results.append(opp.text)
    for opp in schedule_table[0].find_all('td',{'data-stat':'opp_name'}):
        all_results1.append(opp.text)
    for opp in schedule_table[0].find_all('td',{'data-stat':'game_result'}):
        result.append(opp.text)   
    for opp in schedule_table[0].find_all('td',{'data-stat':'pts'}):
        all_results3.append(opp.text)     
    for opp in schedule_table[0].find_all('td',{'data-stat':'opp_pts'}):
        all_results4.append(opp.text)      
    
    home_team = [team.text] * len(result)
    team_result = list(zip(home_team, all_results, all_results1, result, all_results3, all_results4))
    all_teams.append(team_result)
all_teams
# Out:
# [[('Villanova', 'Fri, Nov 11, 2016', 'Lafayette', 'W', '88', '48'),
#   ('Villanova', 'Mon, Nov 14, 2016', 'Purdue\xa0(15)', 'W', '79', '76'),
#   ('Villanova', 'Thu, Nov 17, 2016', 'Western Michigan', 'W', '76', '65'),
#   ('Villanova', 'Fri, Nov 18, 2016', 'Wake Forest', 'W', '96', '77'),
#   ('Villanova', 'Sun, Nov 20, 2016', 'Central Florida', 'W', '67', '57'),
#   ('Villanova', 'Wed, Nov 23, 2016', 'College of Charleston', 'W', '63', '47'),
#   ('Villanova', 'Tue, Nov 29, 2016', 'Pennsylvania', 'W', '82', '57'),
#   ('Villanova', 'Sat, Dec 3, 2016', "Saint Joseph's", 'W', '88', '57'),
#   ('Villanova', 'Tue, Dec 6, 2016', 'La Salle', 'W', '89', '79'),
#   ('Villanova', 'Sat, Dec 10, 2016', 'Notre Dame\xa0(23)', 'W', '74', '66'),
#   ('Villanova', 'Tue, Dec 13, 2016', 'Temple', 'W', '78', '57'),
#   ('Villanova', 'Wed, Dec 21, 2016', 'American', 'W', '90', '48'),
#   ('Villanova', 'Wed, Dec 28, 2016', 'DePaul', 'W', '68', '65'),
#   ('Villanova', 'Sat, Dec 31, 2016', 'Creighton\xa0(10)', 'W', '80', '70'),
#   ('Villanova', 'Wed, Jan 4, 2017', 'Butler\xa0(18)', 'L', '58', '66'),
#   ('Villanova', 'Sat, Jan 7, 2017', 'Marquette', 'W', '93', '81'),
#   ('Villanova', 'Tue, Jan 10, 2017', 'Xavier\xa0(15)', 'W', '79', '54'),
#   ('Villanova', 'Sat, Jan 14, 2017', "St. John's (NY)", 'W', '70', '57'),
#   ('Villanova', 'Mon, Jan 16, 2017', 'Seton Hall', 'W', '76', '46'),
#   ('Villanova', 'Sat, Jan 21, 2017', 'Providence', 'W', '78', '68'),
#   ('Villanova', 'Tue, Jan 24, 2017', 'Marquette', 'L', '72', '74'),
#   ('Villanova', 'Sun, Jan 29, 2017', 'Virginia\xa0(12)', 'W', '61', '59'),
#   ('Villanova', 'Wed, Feb 1, 2017', 'Providence', 'W', '66', '57'),
#   ('Villanova', 'Sat, Feb 4, 2017', "St. John's (NY)", 'W', '92', '79'),
#   ('Villanova', 'Tue, Feb 7, 2017', 'Georgetown', 'W', '75', '64'),
#   ('Villanova', 'Sat, Feb 11, 2017', 'Xavier\xa0(24)', 'W', '73', '57'),
#   ('Villanova', 'Mon, Feb 13, 2017', 'DePaul', 'W', '75', '62'),
#   ('Villanova', 'Sat, Feb 18, 2017', 'Seton Hall', 'W', '92', '70'),
#   ('Villanova', 'Wed, Feb 22, 2017', 'Butler\xa0(22)', 'L', '66', '74'),
#   ('Villanova', 'Sat, Feb 25, 2017', 'Creighton\xa0(23)', 'W', '79', '63'),
#   ('Villanova', 'Sat, Mar 4, 2017', 'Georgetown', 'W', '81', '55'),
#   ('Villanova', 'Thu, Mar 9, 2017', "St. John's (NY)", 'W', '108', '67'),
#   ('Villanova', 'Fri, Mar 10, 2017', 'Seton Hall', 'W', '55', '53'),
#   ('Villanova', 'Sat, Mar 11, 2017', 'Creighton', 'W', '74', '60'),
#   ('Villanova', 'Thu, Mar 16, 2017', "Mount St. Mary's", 'W', '76', '56'),
#   ('Villanova', 'Sat, Mar 18, 2017', 'Wisconsin\xa0(25)', 'L', '62', '65')],
#  [("Mount St. Mary's",
#    'Fri, Nov 11, 2016',
#    'West Virginia\xa0(20)',
#    'L',
#    '59',
#    '87'),
#   ("Mount St. Mary's",
#    'Mon, Nov 14, 2016',
#    'Iowa State\xa0(20)',
#    'L',
#    '55',
#    '73'),
#   ("Mount St. Mary's", 'Wed, Nov 16, 2016', 'Minnesota', 'L', '56', '80'),
#   ("Mount St. Mary's", 'Fri, Nov 18, 2016', 'George Mason', 'W', '78', '76'),
#   ("Mount St. Mary's",
#    'Mon, Nov 21, 2016',
#    'Southern Illinois',
#    'L',
#    '63',
#    '73'),
#   ("Mount St. Mary's",
#    'Wed, Nov 23, 2016',
#    'Texas-Arlington',
#    'L',
#    '71',
#    '80'),
#   ("Mount St. Mary's",
#    'Sat, Nov 26, 2016',
#    'Michigan\xa0(25)',
#    'L',
#    '47',
#    '64'),
#   ("Mount St. Mary's", 'Mon, Nov 28, 2016', 'Arkansas', 'L', '76', '89'),
#   ("Mount St. Mary's", 'Sat, Dec 3, 2016', 'Loyola (MD)', 'L', '57', '64'),
#   ("Mount St. Mary's",
#    'Wed, Dec 7, 2016',
#    'Maryland-Baltimore County',
#    'L',
#    '70',
#    '78'),
#   ("Mount St. Mary's", 'Sat, Dec 10, 2016', 'Lehigh', 'L', '71', '90'),
#   ("Mount St. Mary's", 'Mon, Dec 19, 2016', 'Bucknell', 'L', '65', '81'),
#   ("Mount St. Mary's", 'Thu, Dec 22, 2016', 'Coppin State', 'W', '87', '49'),
#   ("Mount St. Mary's",
#    'Thu, Dec 29, 2016',
#    'Long Island University',
#    'W',
#    '67',
#    '65'),
#   ("Mount St. Mary's", 'Sat, Dec 31, 2016', 'Wagner', 'W', '57', '56'),
#   ("Mount St. Mary's", 'Thu, Jan 5, 2017', 'Bryant', 'L', '71', '72'),
#   ("Mount St. Mary's",
#    'Sat, Jan 7, 2017',
#    'Central Connecticut State',
#    'W',
#    '77',
#    '68'),
#   ("Mount St. Mary's",
#    'Thu, Jan 12, 2017',
#    'Fairleigh Dickinson',
#    'W',
#    '77',
#    '70'),
#   ("Mount St. Mary's",
#    'Sat, Jan 14, 2017',
#    'Saint Francis (PA)',
#    'W',
#    '78',
#    '72'),
#   ("Mount St. Mary's", 'Thu, Jan 19, 2017', 'Sacred Heart', 'W', '86', '75'),
#   ("Mount St. Mary's",
#    'Sat, Jan 21, 2017',
#    'St. Francis (NY)',
#    'W',
#    '55',
#    '47'),
#   ("Mount St. Mary's", 'Thu, Jan 26, 2017', 'Robert Morris', 'W', '48', '47'),
#   ("Mount St. Mary's", 'Sat, Jan 28, 2017', 'Sacred Heart', 'W', '67', '53'),
#   ("Mount St. Mary's", 'Thu, Feb 2, 2017', 'Bryant', 'W', '77', '70'),
#   ("Mount St. Mary's",
#    'Sat, Feb 4, 2017',
#    'Central Connecticut State',
#    'L',
#    '52',
#    '54'),
#   ("Mount St. Mary's", 'Thu, Feb 9, 2017', 'Robert Morris', 'W', '74', '70'),
#   ("Mount St. Mary's",
#    'Sat, Feb 11, 2017',
#    'Saint Francis (PA)',
#    'W',
#    '81',
#    '62'),
#   ("Mount St. Mary's", 'Thu, Feb 16, 2017', 'Wagner', 'L', '65', '69'),
#   ("Mount St. Mary's",
#    'Sat, Feb 18, 2017',
#    'Fairleigh Dickinson',
#    'W',
#    '79',
#    '74'),
#   ("Mount St. Mary's",
#    'Thu, Feb 23, 2017',
#    'Long Island University',
#    'L',
#    '58',
#    '62'),
#   ("Mount St. Mary's",
#    'Sat, Feb 25, 2017',
#    'St. Francis (NY)',
#    'W',
#    '77',
#    '62'),
#   ("Mount St. Mary's", 'Wed, Mar 1, 2017', 'Sacred Heart', 'W', '76', '73'),
#   ("Mount St. Mary's", 'Sat, Mar 4, 2017', 'Robert Morris', 'W', '75', '66'),
#   ("Mount St. Mary's",
#    'Tue, Mar 7, 2017',
#    'Saint Francis (PA)',
#    'W',
#    '71',
#    '61'),
#   ("Mount St. Mary's", 'Tue, Mar 14, 2017', 'New Orleans', 'W', '67', '66'),
#   ("Mount St. Mary's",
#    'Thu, Mar 16, 2017',
#    'Villanova\xa0(1)',
#    'L',
#    '56',
#    '76')],
#  [('Wisconsin', 'Fri, Nov 11, 2016', 'Central Arkansas', 'W', '79', '47'),
#   ('Wisconsin', 'Tue, Nov 15, 2016', 'Creighton\xa0(22)', 'L', '67', '79'),
#   ('Wisconsin', 'Thu, Nov 17, 2016', 'Chicago State', 'W', '69', '51'),
#   ('Wisconsin', 'Mon, Nov 21, 2016', 'Tennessee', 'W', '74', '62'),
#   ('Wisconsin', 'Tue, Nov 22, 2016', 'Georgetown', 'W', '73', '57'),
#   ('Wisconsin', 'Wed, Nov 23, 2016', 'North Carolina\xa0(4)', 'L', '56', '71'),
#   ('Wisconsin', 'Sun, Nov 27, 2016', 'Prairie View', 'W', '95', '50'),
#   ('Wisconsin', 'Tue, Nov 29, 2016', 'Syracuse\xa0(22)', 'W', '77', '60'),
#   ('Wisconsin', 'Sat, Dec 3, 2016', 'Oklahoma', 'W', '90', '70'),
#   ('Wisconsin', 'Wed, Dec 7, 2016', 'Idaho State', 'W', '78', '44'),
#   ('Wisconsin', 'Sat, Dec 10, 2016', 'Marquette', 'W', '93', '84'),
#   ('Wisconsin', 'Wed, Dec 14, 2016', 'Green Bay', 'W', '73', '59'),
#   ('Wisconsin', 'Fri, Dec 23, 2016', 'Florida A&M', 'W', '90', '37'),
#   ('Wisconsin', 'Tue, Dec 27, 2016', 'Rutgers', 'W', '72', '52'),
#   ('Wisconsin', 'Tue, Jan 3, 2017', 'Indiana\xa0(25)', 'W', '75', '68'),
#   ('Wisconsin', 'Sun, Jan 8, 2017', 'Purdue\xa0(20)', 'L', '55', '66'),
#   ('Wisconsin', 'Thu, Jan 12, 2017', 'Ohio State', 'W', '89', '66'),
#   ('Wisconsin', 'Tue, Jan 17, 2017', 'Michigan', 'W', '68', '64'),
#   ('Wisconsin', 'Sat, Jan 21, 2017', 'Minnesota', 'W', '78', '76'),
#   ('Wisconsin', 'Tue, Jan 24, 2017', 'Penn State', 'W', '82', '55'),
#   ('Wisconsin', 'Sat, Jan 28, 2017', 'Rutgers', 'W', '61', '54'),
#   ('Wisconsin', 'Tue, Jan 31, 2017', 'Illinois', 'W', '57', '43'),
#   ('Wisconsin', 'Sun, Feb 5, 2017', 'Indiana', 'W', '65', '60'),
#   ('Wisconsin', 'Thu, Feb 9, 2017', 'Nebraska', 'W', '70', '69'),
#   ('Wisconsin', 'Sun, Feb 12, 2017', 'Northwestern', 'L', '59', '66'),
#   ('Wisconsin', 'Thu, Feb 16, 2017', 'Michigan', 'L', '58', '64'),
#   ('Wisconsin', 'Sun, Feb 19, 2017', 'Maryland\xa0(23)', 'W', '71', '60'),
#   ('Wisconsin', 'Thu, Feb 23, 2017', 'Ohio State', 'L', '73', '83'),
#   ('Wisconsin', 'Sun, Feb 26, 2017', 'Michigan State', 'L', '74', '84'),
#   ('Wisconsin', 'Thu, Mar 2, 2017', 'Iowa', 'L', '57', '59'),
#   ('Wisconsin', 'Sun, Mar 5, 2017', 'Minnesota', 'W', '66', '49'),
#   ('Wisconsin', 'Fri, Mar 10, 2017', 'Indiana', 'W', '70', '60'),
#   ('Wisconsin', 'Sat, Mar 11, 2017', 'Northwestern', 'W', '76', '48'),
#   ('Wisconsin', 'Sun, Mar 12, 2017', 'Michigan', 'L', '56', '71'),
#   ('Wisconsin', 'Thu, Mar 16, 2017', 'Virginia Tech', 'W', '84', '74'),
#   ('Wisconsin', 'Sat, Mar 18, 2017', 'Villanova\xa0(1)', 'W', '65', '62'),
#   ('Wisconsin', 'Fri, Mar 24, 2017', 'Florida\xa0(20)', 'L', '83', '84')],
#  [('Virginia Tech', 'Fri, Nov 11, 2016', 'Maine', 'W', '80', '67'),
#   ('Virginia Tech', 'Tue, Nov 15, 2016', 'High Point', 'W', '99', '73'),
#   ('Virginia Tech',
#    'Sat, Nov 19, 2016',
#    'Virginia Military Institute',
#    'W',
#    '88',
#    '72'),
#   ('Virginia Tech', 'Thu, Nov 24, 2016', 'New Mexico', 'W', '92', '72'),
#   ('Virginia Tech', 'Fri, Nov 25, 2016', 'Texas A&M', 'L', '65', '68'),
#   ('Virginia Tech', 'Sun, Nov 27, 2016', 'Nebraska', 'W', '66', '53'),
#   ('Virginia Tech', 'Wed, Nov 30, 2016', 'Michigan', 'W', '73', '70'),
#   ('Virginia Tech',
#    'Wed, Dec 7, 2016',
#    'Maryland-Eastern Shore',
#    'W',
#    '75',
#    '59'),
#   ('Virginia Tech', 'Sun, Dec 11, 2016', 'Mississippi', 'W', '80', '75'),
#   ('Virginia Tech', 'Sat, Dec 17, 2016', 'Citadel', 'W', '113', '71'),
#   ('Virginia Tech',
#    'Tue, Dec 20, 2016',
#    'Charleston Southern',
#    'W',
#    '87',
#    '59'),
#   ('Virginia Tech',
#    'Wed, Dec 28, 2016',
#    'Maryland-Baltimore County',
#    'W',
#    '87',
#    '70'),
#   ('Virginia Tech', 'Sat, Dec 31, 2016', 'Duke\xa0(5)', 'W', '89', '75'),
#   ('Virginia Tech',
#    'Wed, Jan 4, 2017',
#    'North Carolina State',
#    'L',
#    '78',
#    '104'),
#   ('Virginia Tech',
#    'Sat, Jan 7, 2017',
#    'Florida State\xa0(12)',
#    'L',
#    '78',
#    '93'),
#   ('Virginia Tech', 'Tue, Jan 10, 2017', 'Syracuse', 'W', '83', '73'),
#   ('Virginia Tech',
#    'Sat, Jan 14, 2017',
#    'Notre Dame\xa0(20)',
#    'L',
#    '71',
#    '76'),
#   ('Virginia Tech', 'Wed, Jan 18, 2017', 'Georgia Tech', 'W', '62', '61'),
#   ('Virginia Tech', 'Sun, Jan 22, 2017', 'Clemson', 'W', '82', '81'),
#   ('Virginia Tech',
#    'Thu, Jan 26, 2017',
#    'North Carolina\xa0(9)',
#    'L',
#    '72',
#    '91'),
#   ('Virginia Tech', 'Sun, Jan 29, 2017', 'Boston College', 'W', '85', '79'),
#   ('Virginia Tech', 'Wed, Feb 1, 2017', 'Virginia\xa0(9)', 'L', '48', '71'),
#   ('Virginia Tech', 'Wed, Feb 8, 2017', 'Miami (FL)', 'L', '68', '74'),
#   ('Virginia Tech', 'Sun, Feb 12, 2017', 'Virginia\xa0(12)', 'W', '80', '78'),
#   ('Virginia Tech', 'Tue, Feb 14, 2017', 'Pittsburgh', 'W', '66', '63'),
#   ('Virginia Tech', 'Sat, Feb 18, 2017', 'Louisville\xa0(8)', 'L', '90', '94'),
#   ('Virginia Tech', 'Tue, Feb 21, 2017', 'Clemson', 'W', '71', '70'),
#   ('Virginia Tech', 'Sat, Feb 25, 2017', 'Boston College', 'W', '91', '75'),
#   ('Virginia Tech', 'Mon, Feb 27, 2017', 'Miami (FL)', 'W', '66', '61'),
#   ('Virginia Tech', 'Sat, Mar 4, 2017', 'Wake Forest', 'L', '84', '89'),
#   ('Virginia Tech', 'Wed, Mar 8, 2017', 'Wake Forest', 'W', '99', '90'),
#   ('Virginia Tech',
#    'Thu, Mar 9, 2017',
#    'Florida State\xa0(16)',
#    'L',
#    '68',
#    '74'),
#   ('Virginia Tech',
#    'Thu, Mar 16, 2017',
#    'Wisconsin\xa0(25)',
#    'L',
#    '74',
#    '84')],
#  [('Virginia',
#    'Fri, Nov 11, 2016',
#    'North Carolina-Greensboro',
#    'W',
#    '76',
#    '51'),
#   ('Virginia', 'Tue, Nov 15, 2016', 'St. Francis (NY)', 'W', '72', '32'),
#   ('Virginia', 'Sun, Nov 20, 2016', 'Yale', 'W', '62', '38'),
#   ('Virginia', 'Tue, Nov 22, 2016', 'Grambling', 'W', '90', '34'),
#   ('Virginia', 'Fri, Nov 25, 2016', 'Iowa', 'W', '74', '41'),
#   ('Virginia', 'Sat, Nov 26, 2016', 'Providence', 'W', '63', '52'),
#   ('Virginia', 'Wed, Nov 30, 2016', 'Ohio State', 'W', '63', '61'),
#   ('Virginia', 'Sat, Dec 3, 2016', 'West Virginia\xa0(25)', 'L', '57', '66'),
#   ('Virginia', 'Tue, Dec 6, 2016', 'East Carolina', 'W', '76', '53'),
#   ('Virginia', 'Sat, Dec 17, 2016', 'Robert Morris', 'W', '79', '39'),
#   ('Virginia',
#    'Wed, Dec 21, 2016',
#    'University of California',
#    'W',
#    '56',
#    '52'),
#   ('Virginia', 'Wed, Dec 28, 2016', 'Louisville\xa0(6)', 'W', '61', '53'),
#   ('Virginia', 'Sat, Dec 31, 2016', 'Florida State\xa0(20)', 'L', '58', '60'),
#   ('Virginia', 'Wed, Jan 4, 2017', 'Pittsburgh', 'L', '76', '88'),
#   ('Virginia', 'Sun, Jan 8, 2017', 'Wake Forest', 'W', '79', '62'),
#   ('Virginia', 'Sat, Jan 14, 2017', 'Clemson', 'W', '77', '73'),
#   ('Virginia', 'Wed, Jan 18, 2017', 'Boston College', 'W', '71', '54'),
#   ('Virginia', 'Sat, Jan 21, 2017', 'Georgia Tech', 'W', '62', '49'),
#   ('Virginia', 'Tue, Jan 24, 2017', 'Notre Dame\xa0(14)', 'W', '71', '54'),
#   ('Virginia', 'Sun, Jan 29, 2017', 'Villanova\xa0(1)', 'L', '59', '61'),
#   ('Virginia', 'Wed, Feb 1, 2017', 'Virginia Tech', 'W', '71', '48'),
#   ('Virginia', 'Sat, Feb 4, 2017', 'Syracuse', 'L', '62', '66'),
#   ('Virginia', 'Mon, Feb 6, 2017', 'Louisville\xa0(4)', 'W', '71', '55'),
#   ('Virginia', 'Sun, Feb 12, 2017', 'Virginia Tech', 'L', '78', '80'),
#   ('Virginia', 'Wed, Feb 15, 2017', 'Duke\xa0(12)', 'L', '55', '65'),
#   ('Virginia', 'Sat, Feb 18, 2017', 'North Carolina\xa0(10)', 'L', '41', '65'),
#   ('Virginia', 'Mon, Feb 20, 2017', 'Miami (FL)', 'L', '48', '54'),
#   ('Virginia', 'Sat, Feb 25, 2017', 'North Carolina State', 'W', '70', '55'),
#   ('Virginia', 'Mon, Feb 27, 2017', 'North Carolina\xa0(5)', 'W', '53', '43'),
#   ('Virginia', 'Sat, Mar 4, 2017', 'Pittsburgh', 'W', '67', '42'),
#   ('Virginia', 'Wed, Mar 8, 2017', 'Pittsburgh', 'W', '75', '63'),
#   ('Virginia', 'Thu, Mar 9, 2017', 'Notre Dame\xa0(22)', 'L', '58', '71'),
#   ('Virginia',
#    'Thu, Mar 16, 2017',
#    'North Carolina-Wilmington',
#    'W',
#    '76',
#    '71'),
#   ('Virginia', 'Sat, Mar 18, 2017', 'Florida\xa0(20)', 'L', '39', '65')],
#  [('North Carolina-Wilmington',
#    'Fri, Nov 11, 2016',
#    'Claflin',
#    'W',
#    '110',
#    '64'),
#   ('North Carolina-Wilmington',
#    'Mon, Nov 14, 2016',
#    'Eastern Kentucky',
#    'W',
#    '78',
#    '69'),
#   ('North Carolina-Wilmington',
#    'Sun, Nov 20, 2016',
#    'East Tennessee State',
#    'W',
#    '68',
#    '59'),
#   ('North Carolina-Wilmington',
#    'Fri, Nov 25, 2016',
#    'Middle Tennessee',
#    'L',
#    '63',
#    '68'),
#   ('North Carolina-Wilmington',
#    'Sat, Nov 26, 2016',
#    'Evansville',
#    'W',
#    '65',
#    '62'),
#   ('North Carolina-Wilmington',
#    'Sun, Nov 27, 2016',
#    'Toledo',
#    'W',
#    '102',
#    '77'),
#   ('North Carolina-Wilmington',
#    'Wed, Nov 30, 2016',
#    'Western Michigan',
#    'W',
#    '97',
#    '92'),
#   ('North Carolina-Wilmington',
#    'Sat, Dec 3, 2016',
#    'Pfeiffer',
#    'W',
#    '126',
#    '113'),
#   ('North Carolina-Wilmington',
#    'Sat, Dec 10, 2016',
#    'St. Bonaventure',
#    'W',
#    '81',
#    '80'),
#   ('North Carolina-Wilmington',
#    'Wed, Dec 14, 2016',
#    'Campbell',
#    'W',
#    '96',
#    '75'),
#   ('North Carolina-Wilmington',
#    'Sat, Dec 17, 2016',
#    'Radford',
#    'W',
#    '100',
#    '64'),
#   ('North Carolina-Wilmington',
#    'Tue, Dec 20, 2016',
#    'East Carolina',
#    'W',
#    '81',
#    '71'),
#   ('North Carolina-Wilmington',
#    'Wed, Dec 28, 2016',
#    'Clemson',
#    'L',
#    '73',
#    '87'),
#   ('North Carolina-Wilmington',
#    'Sat, Dec 31, 2016',
#    'Towson',
#    'W',
#    '76',
#    '67'),
#   ('North Carolina-Wilmington', 'Mon, Jan 2, 2017', 'Elon', 'W', '79', '63'),
#   ('North Carolina-Wilmington', 'Thu, Jan 5, 2017', 'Drexel', 'W', '90', '72'),
#   ('North Carolina-Wilmington',
#    'Sat, Jan 7, 2017',
#    'Delaware',
#    'W',
#    '91',
#    '81'),
#   ('North Carolina-Wilmington',
#    'Thu, Jan 12, 2017',
#    'William & Mary',
#    'W',
#    '101',
#    '77'),
#   ('North Carolina-Wilmington',
#    'Sat, Jan 14, 2017',
#    'Hofstra',
#    'W',
#    '84',
#    '76'),
#   ('North Carolina-Wilmington',
#    'Thu, Jan 19, 2017',
#    'College of Charleston',
#    'W',
#    '65',
#    '59'),
#   ('North Carolina-Wilmington',
#    'Sat, Jan 21, 2017',
#    'Drexel',
#    'W',
#    '87',
#    '74'),
#   ('North Carolina-Wilmington',
#    'Thu, Jan 26, 2017',
#    'James Madison',
#    'W',
#    '87',
#    '76'),
#   ('North Carolina-Wilmington',
#    'Sat, Jan 28, 2017',
#    'William & Mary',
#    'L',
#    '78',
#    '96'),
#   ('North Carolina-Wilmington',
#    'Thu, Feb 2, 2017',
#    'College of Charleston',
#    'L',
#    '66',
#    '67'),
#   ('North Carolina-Wilmington',
#    'Sat, Feb 4, 2017',
#    'Delaware',
#    'W',
#    '108',
#    '80'),
#   ('North Carolina-Wilmington',
#    'Thu, Feb 9, 2017',
#    'James Madison',
#    'W',
#    '88',
#    '73'),
#   ('North Carolina-Wilmington', 'Sat, Feb 11, 2017', 'Elon', 'L', '76', '77'),
#   ('North Carolina-Wilmington',
#    'Thu, Feb 16, 2017',
#    'Northeastern',
#    'W',
#    '66',
#    '65'),
#   ('North Carolina-Wilmington',
#    'Sat, Feb 18, 2017',
#    'Hofstra',
#    'W',
#    '83',
#    '76'),
#   ('North Carolina-Wilmington',
#    'Thu, Feb 23, 2017',
#    'Towson',
#    'W',
#    '83',
#    '78'),
#   ('North Carolina-Wilmington',
#    'Sat, Feb 25, 2017',
#    'Northeastern',
#    'W',
#    '74',
#    '65'),
#   ('North Carolina-Wilmington',
#    'Sat, Mar 4, 2017',
#    'Delaware',
#    'W',
#    '91',
#    '82'),
#   ('North Carolina-Wilmington',
#    'Sun, Mar 5, 2017',
#    'William & Mary',
#    'W',
#    '105',
#    '94'),
#   ('North Carolina-Wilmington',
#    'Mon, Mar 6, 2017',
#    'College of Charleston',
#    'W',
#    '78',
#    '69'),
#   ('North Carolina-Wilmington',
#    'Thu, Mar 16, 2017',
#    'Virginia\xa0(24)',
#    'L',
#    '71',
#    '76')],
#  [('Florida', 'Fri, Nov 11, 2016', 'Florida Gulf Coast', 'W', '80', '59'),
#   ('Florida', 'Sun, Nov 13, 2016', 'Mercer', 'W', '76', '54'),
#   ('Florida', 'Thu, Nov 17, 2016', 'St. Bonaventure', 'W', '73', '66'),
#   ('Florida', 'Mon, Nov 21, 2016', 'Belmont', 'W', '78', '61'),
#   ('Florida', 'Thu, Nov 24, 2016', 'Seton Hall', 'W', '81', '76'),
#   ('Florida', 'Fri, Nov 25, 2016', 'Gonzaga\xa0(11)', 'L', '72', '77'),
#   ('Florida', 'Sun, Nov 27, 2016', 'Miami (FL)', 'W', '65', '56'),
#   ('Florida', 'Thu, Dec 1, 2016', 'North Florida', 'W', '91', '60'),
#   ('Florida', 'Tue, Dec 6, 2016', 'Duke\xa0(5)', 'L', '74', '84'),
#   ('Florida', 'Sun, Dec 11, 2016', 'Florida State', 'L', '78', '83'),
#   ('Florida', 'Sat, Dec 17, 2016', 'Charlotte', 'W', '87', '46'),
#   ('Florida', 'Wed, Dec 21, 2016', 'Arkansas-Little Rock', 'W', '94', '71'),
#   ('Florida', 'Thu, Dec 29, 2016', 'Arkansas', 'W', '81', '72'),
#   ('Florida', 'Tue, Jan 3, 2017', 'Mississippi', 'W', '70', '63'),
#   ('Florida', 'Sat, Jan 7, 2017', 'Tennessee', 'W', '83', '70'),
#   ('Florida', 'Tue, Jan 10, 2017', 'Alabama', 'W', '80', '67'),
#   ('Florida', 'Sat, Jan 14, 2017', 'Georgia', 'W', '80', '76'),
#   ('Florida', 'Wed, Jan 18, 2017', 'South Carolina\xa0(24)', 'L', '53', '57'),
#   ('Florida', 'Sat, Jan 21, 2017', 'Vanderbilt', 'L', '66', '68'),
#   ('Florida', 'Wed, Jan 25, 2017', 'Louisiana State', 'W', '106', '71'),
#   ('Florida', 'Sat, Jan 28, 2017', 'Oklahoma', 'W', '84', '52'),
#   ('Florida', 'Thu, Feb 2, 2017', 'Missouri', 'W', '93', '54'),
#   ('Florida', 'Sat, Feb 4, 2017', 'Kentucky\xa0(8)', 'W', '88', '66'),
#   ('Florida', 'Tue, Feb 7, 2017', 'Georgia', 'W', '72', '60'),
#   ('Florida', 'Sat, Feb 11, 2017', 'Texas A&M', 'W', '71', '62'),
#   ('Florida', 'Tue, Feb 14, 2017', 'Auburn', 'W', '114', '95'),
#   ('Florida', 'Sat, Feb 18, 2017', 'Mississippi State', 'W', '57', '52'),
#   ('Florida', 'Tue, Feb 21, 2017', 'South Carolina', 'W', '81', '66'),
#   ('Florida', 'Sat, Feb 25, 2017', 'Kentucky\xa0(11)', 'L', '66', '76'),
#   ('Florida', 'Wed, Mar 1, 2017', 'Arkansas', 'W', '78', '65'),
#   ('Florida', 'Sat, Mar 4, 2017', 'Vanderbilt', 'L', '71', '73'),
#   ('Florida', 'Fri, Mar 10, 2017', 'Vanderbilt', 'L', '62', '72'),
#   ('Florida', 'Thu, Mar 16, 2017', 'East Tennessee State', 'W', '80', '65'),
#   ('Florida', 'Sat, Mar 18, 2017', 'Virginia\xa0(24)', 'W', '65', '39'),
#   ('Florida', 'Fri, Mar 24, 2017', 'Wisconsin\xa0(25)', 'W', '84', '83'),
#   ('Florida', 'Sun, Mar 26, 2017', 'South Carolina', 'L', '70', '77')],
#  [('ETSU', 'Fri, Nov 11, 2016', 'Fordham', 'W', '96', '59'),
#   ('ETSU', 'Mon, Nov 14, 2016', 'Detroit Mercy', 'W', '107', '78'),
#   ('ETSU', 'Sun, Nov 20, 2016', 'North Carolina-Wilmington', 'L', '59', '68'),
#   ('ETSU', 'Fri, Nov 25, 2016', 'Milwaukee', 'W', '86', '62'),
#   ('ETSU', 'Sat, Nov 26, 2016', 'South Dakota State', 'W', '71', '59'),
#   ('ETSU', 'Sun, Nov 27, 2016', 'UC-Irvine', 'W', '72', '66'),
#   ('ETSU', 'Thu, Dec 1, 2016', 'Lees-McRae', 'W', '85', '80'),
#   ('ETSU', 'Sun, Dec 4, 2016', 'Limestone', 'W', '85', '57'),
#   ('ETSU', 'Sat, Dec 10, 2016', 'Dayton', 'L', '61', '75'),
#   ('ETSU', 'Wed, Dec 14, 2016', 'Mississippi State', 'W', '67', '65'),
#   ('ETSU', 'Sat, Dec 17, 2016', 'Morehead State', 'W', '78', '68'),
#   ('ETSU', 'Thu, Dec 22, 2016', 'Tennessee', 'L', '68', '72'),
#   ('ETSU', 'Thu, Dec 29, 2016', 'Savannah State', 'W', '92', '71'),
#   ('ETSU',
#    'Sat, Dec 31, 2016',
#    'Virginia Military Institute',
#    'W',
#    '102',
#    '75'),
#   ('ETSU', 'Thu, Jan 5, 2017', 'Citadel', 'W', '115', '71'),
#   ('ETSU', 'Sat, Jan 7, 2017', 'Mercer', 'W', '67', '58'),
#   ('ETSU', 'Thu, Jan 12, 2017', 'North Carolina-Greensboro', 'L', '79', '83'),
#   ('ETSU', 'Sat, Jan 14, 2017', 'Western Carolina', 'W', '75', '52'),
#   ('ETSU', 'Thu, Jan 19, 2017', 'Furman', 'L', '62', '75'),
#   ('ETSU', 'Sun, Jan 22, 2017', 'Wofford', 'W', '79', '72'),
#   ('ETSU', 'Wed, Jan 25, 2017', 'Samford', 'W', '96', '86'),
#   ('ETSU', 'Sat, Jan 28, 2017', 'Chattanooga', 'W', '76', '71'),
#   ('ETSU', 'Thu, Feb 2, 2017', 'Virginia Military Institute', 'W', '81', '71'),
#   ('ETSU', 'Mon, Feb 6, 2017', 'Wofford', 'L', '76', '79'),
#   ('ETSU', 'Thu, Feb 9, 2017', 'Citadel', 'W', '90', '69'),
#   ('ETSU', 'Sat, Feb 11, 2017', 'Mercer', 'W', '88', '71'),
#   ('ETSU', 'Wed, Feb 15, 2017', 'Samford', 'W', '79', '77'),
#   ('ETSU', 'Sat, Feb 18, 2017', 'Chattanooga', 'W', '65', '51'),
#   ('ETSU', 'Wed, Feb 22, 2017', 'Furman', 'W', '93', '81'),
#   ('ETSU', 'Sat, Feb 25, 2017', 'Western Carolina', 'W', '68', '52'),
#   ('ETSU', 'Mon, Feb 27, 2017', 'North Carolina-Greensboro', 'L', '66', '72'),
#   ('ETSU', 'Sat, Mar 4, 2017', 'Mercer', 'W', '73', '66'),
#   ('ETSU', 'Sun, Mar 5, 2017', 'Samford', 'W', '81', '72'),
#   ('ETSU', 'Mon, Mar 6, 2017', 'North Carolina-Greensboro', 'W', '79', '74'),
#   ('ETSU', 'Thu, Mar 16, 2017', 'Florida\xa0(20)', 'L', '65', '80')],
#  [('SMU', 'Fri, Nov 11, 2016', 'Gardner-Webb', 'W', '72', '44'),
#   ('SMU', 'Sun, Nov 13, 2016', 'Eastern Michigan', 'W', '91', '64'),
#   ('SMU', 'Thu, Nov 17, 2016', 'Pittsburgh', 'W', '76', '67'),
#   ('SMU', 'Fri, Nov 18, 2016', 'Michigan', 'L', '54', '76'),
#   ('SMU', 'Tue, Nov 22, 2016', 'UC-Santa Barbara', 'W', '84', '57'),
#   ('SMU', 'Fri, Nov 25, 2016', 'Southern California', 'L', '73', '78'),
#   ('SMU', 'Wed, Nov 30, 2016', 'Boise State', 'L', '62', '71'),
#   ('SMU', 'Fri, Dec 2, 2016', 'Cal State Bakersfield', 'W', '49', '43'),
#   ('SMU', 'Sun, Dec 4, 2016', 'Delaware State', 'W', '74', '60'),
#   ('SMU', 'Wed, Dec 7, 2016', 'Texas Christian', 'W', '74', '59'),
#   ('SMU', 'Wed, Dec 14, 2016', 'McNeese State', 'W', '92', '56'),
#   ('SMU', 'Mon, Dec 19, 2016', 'Stanford', 'W', '72', '49'),
#   ('SMU', 'Tue, Dec 20, 2016', 'Albany (NY)', 'W', '71', '53'),
#   ('SMU', 'Tue, Dec 27, 2016', 'Memphis', 'W', '58', '54'),
#   ('SMU', 'Sat, Dec 31, 2016', 'East Carolina', 'W', '75', '44'),
#   ('SMU', 'Wed, Jan 4, 2017', 'Temple', 'W', '79', '65'),
#   ('SMU', 'Sat, Jan 7, 2017', 'South Florida', 'W', '84', '65'),
#   ('SMU', 'Thu, Jan 12, 2017', 'Cincinnati\xa0(22)', 'L', '64', '66'),
#   ('SMU', 'Sun, Jan 15, 2017', 'Tulane', 'W', '80', '64'),
#   ('SMU', 'Thu, Jan 19, 2017', 'Connecticut', 'W', '69', '49'),
#   ('SMU', 'Sat, Jan 21, 2017', 'Houston', 'W', '85', '64'),
#   ('SMU', 'Wed, Jan 25, 2017', 'Central Florida', 'W', '65', '60'),
#   ('SMU', 'Wed, Feb 1, 2017', 'East Carolina', 'W', '86', '46'),
#   ('SMU', 'Sat, Feb 4, 2017', 'Tulsa', 'W', '76', '53'),
#   ('SMU', 'Thu, Feb 9, 2017', 'Temple', 'W', '66', '50'),
#   ('SMU', 'Sun, Feb 12, 2017', 'Cincinnati\xa0(11)', 'W', '60', '51'),
#   ('SMU', 'Wed, Feb 15, 2017', 'Tulane', 'W', '80', '75'),
#   ('SMU', 'Sat, Feb 18, 2017', 'Houston', 'W', '76', '66'),
#   ('SMU', 'Sat, Feb 25, 2017', 'Connecticut', 'W', '69', '61'),
#   ('SMU', 'Thu, Mar 2, 2017', 'Tulsa', 'W', '93', '70'),
#   ('SMU', 'Sat, Mar 4, 2017', 'Memphis', 'W', '103', '62'),
#   ('SMU', 'Fri, Mar 10, 2017', 'East Carolina', 'W', '81', '77'),
#   ('SMU', 'Sat, Mar 11, 2017', 'Central Florida', 'W', '70', '59'),
#   ('SMU', 'Sun, Mar 12, 2017', 'Cincinnati\xa0(15)', 'W', '71', '56'),
#   ('SMU', 'Fri, Mar 17, 2017', 'Southern California', 'L', '65', '66')],
#  [('USC', 'Fri, Nov 11, 2016', 'Montana', 'W', '75', '61'),
#   ('USC', 'Sun, Nov 13, 2016', 'Nebraska-Omaha', 'W', '82', '72'),
#   ('USC', 'Fri, Nov 18, 2016', 'Texas A&M', 'W', '65', '63'),
#   ('USC', 'Tue, Nov 22, 2016', 'New Orleans', 'W', '88', '54'),
#   ('USC', 'Fri, Nov 25, 2016', 'Southern Methodist', 'W', '78', '73'),
#   ('USC', 'Sun, Nov 27, 2016', 'UC-Santa Barbara', 'W', '96', '72'),
#   ('USC', 'Wed, Nov 30, 2016', 'San Diego', 'W', '76', '55'),
#   ('USC', 'Sat, Dec 3, 2016', 'Brigham Young', 'W', '91', '84'),
#   ('USC', 'Sun, Dec 11, 2016', 'Pepperdine', 'W', '93', '67'),
#   ('USC', 'Sat, Dec 17, 2016', 'Troy', 'W', '82', '77'),
#   ('USC', 'Mon, Dec 19, 2016', 'Cornell', 'W', '79', '67'),
#   ('USC', 'Thu, Dec 22, 2016', 'Missouri State', 'W', '83', '75'),
#   ('USC', 'Fri, Dec 23, 2016', 'Wyoming', 'W', '94', '92'),
#   ('USC', 'Wed, Dec 28, 2016', 'Oregon State', 'W', '70', '63'),
#   ('USC', 'Fri, Dec 30, 2016', 'Oregon\xa0(21)', 'L', '61', '84'),
#   ('USC', 'Thu, Jan 5, 2017', 'Stanford', 'W', '72', '56'),
#   ('USC', 'Sun, Jan 8, 2017', 'University of California', 'L', '73', '74'),
#   ('USC', 'Thu, Jan 12, 2017', 'Utah', 'L', '64', '86'),
#   ('USC', 'Sun, Jan 15, 2017', 'Colorado', 'W', '71', '68'),
#   ('USC', 'Thu, Jan 19, 2017', 'Arizona\xa0(14)', 'L', '66', '73'),
#   ('USC', 'Sun, Jan 22, 2017', 'Arizona State', 'W', '82', '79'),
#   ('USC', 'Wed, Jan 25, 2017', 'UCLA\xa0(8)', 'W', '84', '76'),
#   ('USC', 'Wed, Feb 1, 2017', 'Washington', 'W', '82', '74'),
#   ('USC', 'Sat, Feb 4, 2017', 'Washington State', 'W', '86', '77'),
#   ('USC', 'Thu, Feb 9, 2017', 'Oregon State', 'W', '92', '66'),
#   ('USC', 'Sat, Feb 11, 2017', 'Oregon\xa0(5)', 'L', '70', '81'),
#   ('USC', 'Sat, Feb 18, 2017', 'UCLA\xa0(6)', 'L', '70', '102'),
#   ('USC', 'Thu, Feb 23, 2017', 'Arizona\xa0(4)', 'L', '77', '90'),
#   ('USC', 'Sun, Feb 26, 2017', 'Arizona State', 'L', '82', '83'),
#   ('USC', 'Wed, Mar 1, 2017', 'Washington State', 'W', '87', '64'),
#   ('USC', 'Sat, Mar 4, 2017', 'Washington', 'W', '74', '58'),
#   ('USC', 'Wed, Mar 8, 2017', 'Washington', 'W', '78', '73'),
#   ('USC', 'Thu, Mar 9, 2017', 'UCLA\xa0(3)', 'L', '74', '76'),
#   ('USC', 'Wed, Mar 15, 2017', 'Providence', 'W', '75', '71'),
#   ('USC', 'Fri, Mar 17, 2017', 'Southern Methodist\xa0(11)', 'W', '66', '65'),
#   ('USC', 'Sun, Mar 19, 2017', 'Baylor\xa0(12)', 'L', '78', '82')],
#  [('Baylor', 'Fri, Nov 11, 2016', 'Oral Roberts', 'W', '76', '61'),
#   ('Baylor', 'Tue, Nov 15, 2016', 'Oregon\xa0(4)', 'W', '66', '49'),
#   ('Baylor', 'Fri, Nov 18, 2016', 'Florida Gulf Coast', 'W', '81', '72'),
#   ('Baylor', 'Wed, Nov 23, 2016', 'Virginia Commonwealth', 'W', '71', '63'),
#   ('Baylor', 'Thu, Nov 24, 2016', 'Michigan State\xa0(24)', 'W', '73', '58'),
#   ('Baylor', 'Fri, Nov 25, 2016', 'Louisville\xa0(10)', 'W', '66', '63'),
#   ('Baylor', 'Wed, Nov 30, 2016', 'Sam Houston State', 'W', '79', '45'),
#   ('Baylor', 'Sat, Dec 3, 2016', 'Xavier\xa0(7)', 'W', '76', '61'),
#   ('Baylor', 'Wed, Dec 14, 2016', 'Southern', 'W', '89', '59'),
#   ('Baylor', 'Sat, Dec 17, 2016', 'Jackson State', 'W', '82', '57'),
#   ('Baylor', 'Sun, Dec 18, 2016', 'John Brown', 'W', '107', '53'),
#   ('Baylor', 'Wed, Dec 21, 2016', 'Texas Southern', 'W', '89', '63'),
#   ('Baylor', 'Fri, Dec 30, 2016', 'Oklahoma', 'W', '76', '50'),
#   ('Baylor', 'Wed, Jan 4, 2017', 'Iowa State', 'W', '65', '63'),
#   ('Baylor', 'Sat, Jan 7, 2017', 'Oklahoma State', 'W', '61', '57'),
#   ('Baylor', 'Tue, Jan 10, 2017', 'West Virginia\xa0(10)', 'L', '68', '89'),
#   ('Baylor', 'Sat, Jan 14, 2017', 'Kansas State\xa0(25)', 'W', '77', '68'),
#   ('Baylor', 'Tue, Jan 17, 2017', 'Texas', 'W', '74', '64'),
#   ('Baylor', 'Sat, Jan 21, 2017', 'Texas Christian', 'W', '62', '53'),
#   ('Baylor', 'Wed, Jan 25, 2017', 'Texas Tech', 'W', '65', '61'),
#   ('Baylor', 'Sat, Jan 28, 2017', 'Mississippi', 'W', '78', '75'),
#   ('Baylor', 'Wed, Feb 1, 2017', 'Kansas\xa0(3)', 'L', '68', '73'),
#   ('Baylor', 'Sat, Feb 4, 2017', 'Kansas State', 'L', '54', '56'),
#   ('Baylor', 'Wed, Feb 8, 2017', 'Oklahoma State', 'W', '72', '69'),
#   ('Baylor', 'Sat, Feb 11, 2017', 'Texas Christian', 'W', '70', '52'),
#   ('Baylor', 'Mon, Feb 13, 2017', 'Texas Tech', 'L', '78', '84'),
#   ('Baylor', 'Sat, Feb 18, 2017', 'Kansas\xa0(3)', 'L', '65', '67'),
#   ('Baylor', 'Tue, Feb 21, 2017', 'Oklahoma', 'W', '60', '54'),
#   ('Baylor', 'Sat, Feb 25, 2017', 'Iowa State', 'L', '69', '72'),
#   ('Baylor', 'Mon, Feb 27, 2017', 'West Virginia\xa0(10)', 'W', '71', '62'),
#   ('Baylor', 'Sat, Mar 4, 2017', 'Texas', 'W', '75', '64'),
#   ('Baylor', 'Thu, Mar 9, 2017', 'Kansas State', 'L', '64', '70'),
#   ('Baylor', 'Fri, Mar 17, 2017', 'New Mexico State', 'W', '91', '73'),
#   ('Baylor', 'Sun, Mar 19, 2017', 'Southern California', 'W', '82', '78'),
#   ('Baylor', 'Fri, Mar 24, 2017', 'South Carolina', 'L', '50', '70')],
#  [('New Mexico State',
#    'Fri, Nov 11, 2016',
#    'Arizona Christian',
#    'W',
#    '100',
#    '52'),
#   ('New Mexico State', 'Sun, Nov 13, 2016', 'Colorado State', 'L', '61', '64'),
#   ('New Mexico State', 'Wed, Nov 16, 2016', 'Samford', 'W', '58', '48'),
#   ('New Mexico State', 'Fri, Nov 18, 2016', 'New Mexico', 'L', '59', '72'),
#   ('New Mexico State',
#    'Sun, Nov 20, 2016',
#    'Bethune-Cookman',
#    'W',
#    '89',
#    '73'),
#   ('New Mexico State', 'Tue, Nov 22, 2016', 'Nicholls State', 'W', '86', '74'),
#   ('New Mexico State', 'Sat, Nov 26, 2016', 'San Diego', 'W', '56', '51'),
#   ('New Mexico State', 'Wed, Nov 30, 2016', 'Air Force', 'W', '78', '70'),
#   ('New Mexico State',
#    'Sat, Dec 3, 2016',
#    'Long Beach State',
#    'W',
#    '93',
#    '85'),
#   ('New Mexico State', 'Sat, Dec 10, 2016', 'New Mexico', 'W', '84', '71'),
#   ('New Mexico State', 'Tue, Dec 13, 2016', 'Texas-El Paso', 'W', '79', '68'),
#   ('New Mexico State', 'Sat, Dec 17, 2016', 'Arizona State', 'W', '81', '70'),
#   ('New Mexico State', 'Mon, Dec 19, 2016', 'UC-Irvine', 'W', '85', '79'),
#   ('New Mexico State',
#    'Tue, Dec 27, 2016',
#    'Eastern New Mexico',
#    'W',
#    '84',
#    '50'),
#   ('New Mexico State', 'Fri, Dec 30, 2016', 'Texas-El Paso', 'W', '79', '70'),
#   ('New Mexico State',
#    'Thu, Jan 5, 2017',
#    'Missouri-Kansas City',
#    'W',
#    '77',
#    '64'),
#   ('New Mexico State', 'Sat, Jan 7, 2017', 'Chicago State', 'W', '78', '62'),
#   ('New Mexico State', 'Thu, Jan 12, 2017', 'Grand Canyon', 'W', '81', '69'),
#   ('New Mexico State',
#    'Sat, Jan 14, 2017',
#    'Cal State Bakersfield',
#    'W',
#    '63',
#    '58'),
#   ('New Mexico State',
#    'Sat, Jan 21, 2017',
#    'Missouri-Kansas City',
#    'W',
#    '94',
#    '71'),
#   ('New Mexico State', 'Thu, Jan 26, 2017', 'Seattle', 'W', '71', '56'),
#   ('New Mexico State', 'Sat, Jan 28, 2017', 'Utah Valley', 'W', '74', '69'),
#   ('New Mexico State',
#    'Mon, Jan 30, 2017',
#    'Northern New Mexico',
#    'W',
#    '98',
#    '75'),
#   ('New Mexico State', 'Sat, Feb 4, 2017', 'Chicago State', 'W', '86', '51'),
#   ('New Mexico State',
#    'Thu, Feb 9, 2017',
#    'Cal State Bakersfield',
#    'L',
#    '53',
#    '72'),
#   ('New Mexico State', 'Sat, Feb 11, 2017', 'Grand Canyon', 'L', '71', '83'),
#   ('New Mexico State',
#    'Sat, Feb 18, 2017',
#    'Texas-Rio Grande Valley',
#    'W',
#    '107',
#    '101'),
#   ('New Mexico State', 'Thu, Feb 23, 2017', 'Utah Valley', 'L', '72', '84'),
#   ('New Mexico State', 'Sat, Feb 25, 2017', 'Seattle', 'W', '86', '53'),
#   ('New Mexico State',
#    'Sat, Mar 4, 2017',
#    'Texas-Rio Grande Valley',
#    'W',
#    '107',
#    '81'),
#   ('New Mexico State', 'Thu, Mar 9, 2017', 'Chicago State', 'W', '67', '53'),
#   ('New Mexico State',
#    'Fri, Mar 10, 2017',
#    'Missouri-Kansas City',
#    'W',
#    '78',
#    '60'),
#   ('New Mexico State',
#    'Sat, Mar 11, 2017',
#    'Cal State Bakersfield',
#    'W',
#    '70',
#    '60'),
#   ('New Mexico State',
#    'Fri, Mar 17, 2017',
#    'Baylor\xa0(12)',
#    'L',
#    '73',
#    '91')],
#  [('South Carolina', 'Fri, Nov 11, 2016', 'Louisiana Tech', 'W', '85', '76'),
#   ('South Carolina', 'Sun, Nov 13, 2016', 'Holy Cross', 'W', '81', '49'),
#   ('South Carolina', 'Tue, Nov 15, 2016', 'Monmouth', 'W', '70', '69'),
#   ('South Carolina',
#    'Fri, Nov 18, 2016',
#    'South Carolina State',
#    'W',
#    '92',
#    '50'),
#   ('South Carolina', 'Wed, Nov 23, 2016', 'Michigan\xa0(25)', 'W', '61', '46'),
#   ('South Carolina', 'Sat, Nov 26, 2016', 'Syracuse\xa0(18)', 'W', '64', '50'),
#   ('South Carolina', 'Thu, Dec 1, 2016', 'Vermont', 'W', '68', '50'),
#   ('South Carolina',
#    'Sun, Dec 4, 2016',
#    'Florida International',
#    'W',
#    '70',
#    '54'),
#   ('South Carolina', 'Mon, Dec 12, 2016', 'Seton Hall', 'L', '64', '67'),
#   ('South Carolina', 'Sat, Dec 17, 2016', 'South Florida', 'W', '77', '66'),
#   ('South Carolina', 'Wed, Dec 21, 2016', 'Clemson', 'L', '60', '62'),
#   ('South Carolina', 'Tue, Dec 27, 2016', 'Lander', 'W', '90', '62'),
#   ('South Carolina', 'Fri, Dec 30, 2016', 'Memphis', 'L', '54', '70'),
#   ('South Carolina', 'Wed, Jan 4, 2017', 'Georgia', 'W', '67', '61'),
#   ('South Carolina', 'Sat, Jan 7, 2017', 'Texas A&M', 'W', '79', '68'),
#   ('South Carolina', 'Wed, Jan 11, 2017', 'Tennessee', 'W', '70', '60'),
#   ('South Carolina', 'Sat, Jan 14, 2017', 'Mississippi', 'W', '67', '56'),
#   ('South Carolina', 'Wed, Jan 18, 2017', 'Florida\xa0(19)', 'W', '57', '53'),
#   ('South Carolina', 'Sat, Jan 21, 2017', 'Kentucky\xa0(5)', 'L', '69', '85'),
#   ('South Carolina', 'Tue, Jan 24, 2017', 'Auburn', 'W', '98', '69'),
#   ('South Carolina', 'Sat, Jan 28, 2017', 'Missouri', 'W', '63', '53'),
#   ('South Carolina', 'Wed, Feb 1, 2017', 'Louisiana State', 'W', '88', '63'),
#   ('South Carolina', 'Sat, Feb 4, 2017', 'Georgia', 'W', '77', '75'),
#   ('South Carolina', 'Tue, Feb 7, 2017', 'Alabama', 'L', '86', '90'),
#   ('South Carolina',
#    'Sat, Feb 11, 2017',
#    'Mississippi State',
#    'W',
#    '77',
#    '73'),
#   ('South Carolina', 'Wed, Feb 15, 2017', 'Arkansas', 'L', '76', '83'),
#   ('South Carolina', 'Sat, Feb 18, 2017', 'Vanderbilt', 'L', '62', '71'),
#   ('South Carolina', 'Tue, Feb 21, 2017', 'Florida\xa0(13)', 'L', '66', '81'),
#   ('South Carolina', 'Sat, Feb 25, 2017', 'Tennessee', 'W', '82', '55'),
#   ('South Carolina',
#    'Tue, Feb 28, 2017',
#    'Mississippi State',
#    'W',
#    '63',
#    '57'),
#   ('South Carolina', 'Sat, Mar 4, 2017', 'Mississippi', 'L', '70', '75'),
#   ('South Carolina', 'Fri, Mar 10, 2017', 'Alabama', 'L', '53', '64'),
#   ('South Carolina', 'Fri, Mar 17, 2017', 'Marquette', 'W', '93', '73'),
#   ('South Carolina', 'Sun, Mar 19, 2017', 'Duke\xa0(7)', 'W', '88', '81'),
#   ('South Carolina', 'Fri, Mar 24, 2017', 'Baylor\xa0(12)', 'W', '70', '50'),
#   ('South Carolina', 'Sun, Mar 26, 2017', 'Florida\xa0(20)', 'W', '77', '70'),
#   ('South Carolina', 'Sat, Apr 1, 2017', 'Gonzaga\xa0(2)', 'L', '73', '77')],
#  [('Marquette', 'Fri, Nov 11, 2016', 'Vanderbilt', 'W', '95', '71'),
#   ('Marquette', 'Mon, Nov 14, 2016', 'Howard', 'W', '81', '49'),
#   ('Marquette', 'Thu, Nov 17, 2016', 'Michigan', 'L', '61', '79'),
#   ('Marquette', 'Fri, Nov 18, 2016', 'Pittsburgh', 'L', '75', '78'),
#   ('Marquette', 'Tue, Nov 22, 2016', 'IUPUI', 'W', '104', '79'),
#   ('Marquette', 'Sat, Nov 26, 2016', 'Houston Baptist', 'W', '101', '79'),
#   ('Marquette', 'Wed, Nov 30, 2016', 'Western Carolina', 'W', '90', '44'),
#   ('Marquette', 'Sun, Dec 4, 2016', 'Georgia', 'W', '89', '79'),
#   ('Marquette', 'Tue, Dec 6, 2016', 'Fresno State', 'W', '84', '81'),
#   ('Marquette', 'Sat, Dec 10, 2016', 'Wisconsin\xa0(17)', 'L', '84', '93'),
#   ('Marquette', 'Mon, Dec 19, 2016', 'Saint Francis (PA)', 'W', '78', '65'),
#   ('Marquette',
#    'Wed, Dec 21, 2016',
#    'Southern Illinois-Edwardsville',
#    'W',
#    '89',
#    '56'),
#   ('Marquette', 'Wed, Dec 28, 2016', 'Georgetown', 'W', '76', '66'),
#   ('Marquette', 'Sun, Jan 1, 2017', 'Seton Hall', 'L', '66', '69'),
#   ('Marquette', 'Sat, Jan 7, 2017', 'Villanova\xa0(1)', 'L', '81', '93'),
#   ('Marquette', 'Wed, Jan 11, 2017', 'Seton Hall', 'W', '89', '86'),
#   ('Marquette', 'Sat, Jan 14, 2017', 'DePaul', 'W', '83', '58'),
#   ('Marquette', 'Mon, Jan 16, 2017', 'Butler\xa0(13)', 'L', '80', '88'),
#   ('Marquette', 'Sat, Jan 21, 2017', 'Creighton\xa0(7)', 'W', '102', '94'),
#   ('Marquette', 'Tue, Jan 24, 2017', 'Villanova\xa0(1)', 'W', '74', '72'),
#   ('Marquette', 'Sat, Jan 28, 2017', 'Providence', 'L', '78', '79'),
#   ('Marquette', 'Wed, Feb 1, 2017', "St. John's (NY)", 'L', '72', '86'),
#   ('Marquette', 'Sat, Feb 4, 2017', 'DePaul', 'W', '92', '79'),
#   ('Marquette', 'Tue, Feb 7, 2017', 'Butler\xa0(22)', 'L', '65', '68'),
#   ('Marquette', 'Sat, Feb 11, 2017', 'Georgetown', 'L', '62', '80'),
#   ('Marquette', 'Sat, Feb 18, 2017', 'Xavier', 'W', '83', '61'),
#   ('Marquette', 'Tue, Feb 21, 2017', "St. John's (NY)", 'W', '93', '71'),
#   ('Marquette', 'Sat, Feb 25, 2017', 'Providence', 'L', '69', '73'),
#   ('Marquette', 'Wed, Mar 1, 2017', 'Xavier', 'W', '95', '84'),
#   ('Marquette', 'Sat, Mar 4, 2017', 'Creighton', 'W', '91', '83'),
#   ('Marquette', 'Thu, Mar 9, 2017', 'Seton Hall', 'L', '76', '82'),
#   ('Marquette', 'Fri, Mar 17, 2017', 'South Carolina', 'L', '73', '93')],
#  [('Duke', 'Fri, Nov 11, 2016', 'Marist', 'W', '94', '49'),
#   ('Duke', 'Sat, Nov 12, 2016', 'Grand Canyon', 'W', '96', '61'),
#   ('Duke', 'Tue, Nov 15, 2016', 'Kansas\xa0(7)', 'L', '75', '77'),
#   ('Duke', 'Sat, Nov 19, 2016', 'Penn State', 'W', '78', '68'),
#   ('Duke', 'Sun, Nov 20, 2016', 'Rhode Island\xa0(21)', 'W', '75', '65'),
#   ('Duke', 'Wed, Nov 23, 2016', 'William & Mary', 'W', '88', '67'),
#   ('Duke', 'Sat, Nov 26, 2016', 'Appalachian State', 'W', '93', '58'),
#   ('Duke', 'Tue, Nov 29, 2016', 'Michigan State', 'W', '78', '69'),
#   ('Duke', 'Sat, Dec 3, 2016', 'Maine', 'W', '94', '55'),
#   ('Duke', 'Tue, Dec 6, 2016', 'Florida\xa0(21)', 'W', '84', '74'),
#   ('Duke', 'Sat, Dec 10, 2016', 'Nevada-Las Vegas', 'W', '94', '45'),
#   ('Duke', 'Mon, Dec 19, 2016', 'Tennessee State', 'W', '65', '55'),
#   ('Duke', 'Wed, Dec 21, 2016', 'Elon', 'W', '72', '61'),
#   ('Duke', 'Sat, Dec 31, 2016', 'Virginia Tech', 'L', '75', '89'),
#   ('Duke', 'Wed, Jan 4, 2017', 'Georgia Tech', 'W', '110', '57'),
#   ('Duke', 'Sat, Jan 7, 2017', 'Boston College', 'W', '93', '82'),
#   ('Duke', 'Tue, Jan 10, 2017', 'Florida State\xa0(9)', 'L', '72', '88'),
#   ('Duke', 'Sat, Jan 14, 2017', 'Louisville\xa0(14)', 'L', '69', '78'),
#   ('Duke', 'Sat, Jan 21, 2017', 'Miami (FL)', 'W', '70', '58'),
#   ('Duke', 'Mon, Jan 23, 2017', 'North Carolina State', 'L', '82', '84'),
#   ('Duke', 'Sat, Jan 28, 2017', 'Wake Forest', 'W', '85', '83'),
#   ('Duke', 'Mon, Jan 30, 2017', 'Notre Dame\xa0(20)', 'W', '84', '74'),
#   ('Duke', 'Sat, Feb 4, 2017', 'Pittsburgh', 'W', '72', '64'),
#   ('Duke', 'Thu, Feb 9, 2017', 'North Carolina\xa0(8)', 'W', '86', '78'),
#   ('Duke', 'Sat, Feb 11, 2017', 'Clemson', 'W', '64', '62'),
#   ('Duke', 'Wed, Feb 15, 2017', 'Virginia\xa0(14)', 'W', '65', '55'),
#   ('Duke', 'Sat, Feb 18, 2017', 'Wake Forest', 'W', '99', '94'),
#   ('Duke', 'Wed, Feb 22, 2017', 'Syracuse', 'L', '75', '78'),
#   ('Duke', 'Sat, Feb 25, 2017', 'Miami (FL)', 'L', '50', '55'),
#   ('Duke', 'Tue, Feb 28, 2017', 'Florida State\xa0(15)', 'W', '75', '70'),
#   ('Duke', 'Sat, Mar 4, 2017', 'North Carolina\xa0(5)', 'L', '83', '90'),
#   ('Duke', 'Wed, Mar 8, 2017', 'Clemson', 'W', '79', '72'),
#   ('Duke', 'Thu, Mar 9, 2017', 'Louisville\xa0(10)', 'W', '81', '77'),
#   ('Duke', 'Fri, Mar 10, 2017', 'North Carolina\xa0(6)', 'W', '93', '83'),
#   ('Duke', 'Sat, Mar 11, 2017', 'Notre Dame\xa0(22)', 'W', '75', '69'),
#   ('Duke', 'Fri, Mar 17, 2017', 'Troy', 'W', '87', '65'),
#   ('Duke', 'Sun, Mar 19, 2017', 'South Carolina', 'L', '81', '88')],
#  [('Troy', 'Fri, Nov 11, 2016', 'Toccoa Falls', 'W', '135', '76'),
#   ('Troy', 'Mon, Nov 14, 2016', 'Eastern Illinois', 'W', '70', '67'),
#   ('Troy', 'Thu, Nov 17, 2016', 'Alabama-Birmingham', 'L', '51', '74'),
#   ('Troy', 'Mon, Nov 21, 2016', 'Eastern Illinois', 'L', '67', '71'),
#   ('Troy', 'Wed, Nov 23, 2016', 'San Francisco', 'L', '67', '79'),
#   ('Troy', 'Fri, Nov 25, 2016', 'Hawaii', 'W', '65', '63'),
#   ('Troy', 'Thu, Dec 1, 2016', 'South Florida', 'L', '74', '80'),
#   ('Troy', 'Sun, Dec 4, 2016', 'Alabama State', 'W', '83', '65'),
#   ('Troy', 'Sat, Dec 10, 2016', 'Alabama A&M', 'W', '88', '59'),
#   ('Troy', 'Wed, Dec 14, 2016', 'Point University', 'W', '114', '52'),
#   ('Troy',
#    'Sat, Dec 17, 2016',
#    'Southern California\xa0(24)',
#    'L',
#    '77',
#    '82'),
#   ('Troy', 'Mon, Dec 19, 2016', 'Wyoming', 'L', '66', '72'),
#   ('Troy', 'Thu, Dec 22, 2016', 'Cornell', 'W', '92', '84'),
#   ('Troy', 'Fri, Dec 23, 2016', 'Chicago State', 'W', '83', '65'),
#   ('Troy', 'Mon, Jan 2, 2017', 'South Alabama', 'L', '75', '76'),
#   ('Troy', 'Sat, Jan 7, 2017', 'Georgia Southern', 'L', '82', '86'),
#   ('Troy', 'Mon, Jan 9, 2017', 'Georgia State', 'W', '80', '77'),
#   ('Troy', 'Sat, Jan 14, 2017', 'Texas-Arlington', 'W', '93', '71'),
#   ('Troy', 'Mon, Jan 16, 2017', 'Texas State', 'L', '71', '75'),
#   ('Troy', 'Sat, Jan 21, 2017', 'Arkansas State', 'L', '80', '82'),
#   ('Troy', 'Mon, Jan 23, 2017', 'Arkansas-Little Rock', 'W', '78', '69'),
#   ('Troy', 'Sat, Jan 28, 2017', 'Georgia State', 'L', '72', '78'),
#   ('Troy', 'Mon, Jan 30, 2017', 'Georgia Southern', 'W', '83', '76'),
#   ('Troy', 'Sat, Feb 4, 2017', 'South Alabama', 'L', '71', '76'),
#   ('Troy', 'Sat, Feb 11, 2017', 'Louisiana-Lafayette', 'W', '100', '88'),
#   ('Troy', 'Mon, Feb 13, 2017', 'Louisiana-Monroe', 'W', '73', '72'),
#   ('Troy', 'Sat, Feb 18, 2017', 'Coastal Carolina', 'W', '87', '78'),
#   ('Troy', 'Mon, Feb 20, 2017', 'Appalachian State', 'W', '76', '66'),
#   ('Troy', 'Sat, Feb 25, 2017', 'Texas State', 'L', '59', '63'),
#   ('Troy', 'Mon, Feb 27, 2017', 'Texas-Arlington', 'L', '67', '82'),
#   ('Troy', 'Thu, Mar 2, 2017', 'Arkansas State', 'W', '81', '72'),
#   ('Troy', 'Sat, Mar 4, 2017', 'Arkansas-Little Rock', 'W', '57', '54'),
#   ('Troy', 'Wed, Mar 8, 2017', 'Appalachian State', 'W', '84', '64'),
#   ('Troy', 'Fri, Mar 10, 2017', 'Georgia Southern', 'W', '90', '70'),
#   ('Troy', 'Sat, Mar 11, 2017', 'Georgia State', 'W', '74', '63'),
#   ('Troy', 'Sun, Mar 12, 2017', 'Texas State', 'W', '59', '53'),
#   ('Troy', 'Fri, Mar 17, 2017', 'Duke\xa0(7)', 'L', '65', '87')],
#  [('Kansas', 'Fri, Nov 11, 2016', 'Indiana\xa0(11)', 'L', '99', '103'),
#   ('Kansas', 'Tue, Nov 15, 2016', 'Duke\xa0(1)', 'W', '77', '75'),
#   ('Kansas', 'Fri, Nov 18, 2016', 'Siena', 'W', '86', '65'),
#   ('Kansas', 'Mon, Nov 21, 2016', 'Alabama-Birmingham', 'W', '83', '63'),
#   ('Kansas', 'Tue, Nov 22, 2016', 'Georgia', 'W', '65', '54'),
#   ('Kansas', 'Fri, Nov 25, 2016', 'North Carolina-Asheville', 'W', '95', '57'),
#   ('Kansas', 'Tue, Nov 29, 2016', 'Long Beach State', 'W', '91', '61'),
#   ('Kansas', 'Sat, Dec 3, 2016', 'Stanford', 'W', '89', '74'),
#   ('Kansas', 'Tue, Dec 6, 2016', 'Missouri-Kansas City', 'W', '105', '62'),
#   ('Kansas', 'Sat, Dec 10, 2016', 'Nebraska', 'W', '89', '72'),
#   ('Kansas', 'Sat, Dec 17, 2016', 'Davidson', 'W', '89', '71'),
#   ('Kansas', 'Thu, Dec 22, 2016', 'Nevada-Las Vegas', 'W', '71', '53'),
#   ('Kansas', 'Fri, Dec 30, 2016', 'Texas Christian', 'W', '86', '80'),
#   ('Kansas', 'Tue, Jan 3, 2017', 'Kansas State', 'W', '90', '88'),
#   ('Kansas', 'Sat, Jan 7, 2017', 'Texas Tech', 'W', '85', '68'),
#   ('Kansas', 'Tue, Jan 10, 2017', 'Oklahoma', 'W', '81', '70'),
#   ('Kansas', 'Sat, Jan 14, 2017', 'Oklahoma State', 'W', '87', '80'),
#   ('Kansas', 'Mon, Jan 16, 2017', 'Iowa State', 'W', '76', '72'),
#   ('Kansas', 'Sat, Jan 21, 2017', 'Texas', 'W', '79', '67'),
#   ('Kansas', 'Tue, Jan 24, 2017', 'West Virginia\xa0(18)', 'L', '69', '85'),
#   ('Kansas', 'Sat, Jan 28, 2017', 'Kentucky\xa0(4)', 'W', '79', '73'),
#   ('Kansas', 'Wed, Feb 1, 2017', 'Baylor\xa0(2)', 'W', '73', '68'),
#   ('Kansas', 'Sat, Feb 4, 2017', 'Iowa State', 'L', '89', '92'),
#   ('Kansas', 'Mon, Feb 6, 2017', 'Kansas State', 'W', '74', '71'),
#   ('Kansas', 'Sat, Feb 11, 2017', 'Texas Tech', 'W', '80', '79'),
#   ('Kansas', 'Mon, Feb 13, 2017', 'West Virginia\xa0(9)', 'W', '84', '80'),
#   ('Kansas', 'Sat, Feb 18, 2017', 'Baylor\xa0(4)', 'W', '67', '65'),
#   ('Kansas', 'Wed, Feb 22, 2017', 'Texas Christian', 'W', '87', '68'),
#   ('Kansas', 'Sat, Feb 25, 2017', 'Texas', 'W', '77', '67'),
#   ('Kansas', 'Mon, Feb 27, 2017', 'Oklahoma', 'W', '73', '63'),
#   ('Kansas', 'Sat, Mar 4, 2017', 'Oklahoma State', 'W', '90', '85'),
#   ('Kansas', 'Thu, Mar 9, 2017', 'Texas Christian', 'L', '82', '85'),
#   ('Kansas', 'Fri, Mar 17, 2017', 'UC-Davis', 'W', '100', '62'),
#   ('Kansas', 'Sun, Mar 19, 2017', 'Michigan State', 'W', '90', '70'),
#   ('Kansas', 'Thu, Mar 23, 2017', 'Purdue\xa0(15)', 'W', '98', '66'),
#   ('Kansas', 'Sat, Mar 25, 2017', 'Oregon\xa0(9)', 'L', '60', '74')],
#  [('UC-Davis', 'Fri, Nov 11, 2016', 'Tennessee State', 'L', '64', '78'),
#   ('UC-Davis', 'Sat, Nov 12, 2016', 'Santa Clara', 'W', '63', '58'),
#   ('UC-Davis', 'Sun, Nov 13, 2016', 'Northern Arizona', 'W', '89', '76'),
#   ('UC-Davis', 'Thu, Nov 17, 2016', 'Holy Names', 'W', '89', '75'),
#   ('UC-Davis', 'Mon, Nov 21, 2016', 'Sacramento State', 'W', '81', '72'),
#   ('UC-Davis', 'Thu, Nov 24, 2016', 'Weber State', 'L', '58', '86'),
#   ('UC-Davis', 'Fri, Nov 25, 2016', 'Drake', 'W', '64', '58'),
#   ('UC-Davis', 'Sat, Nov 26, 2016', 'Oakland', 'L', '66', '79'),
#   ('UC-Davis', 'Sat, Dec 3, 2016', 'Idaho', 'L', '66', '68'),
#   ('UC-Davis',
#    'Sat, Dec 10, 2016',
#    'University of California',
#    'L',
#    '61',
#    '86'),
#   ('UC-Davis', 'Wed, Dec 14, 2016', 'North Dakota State', 'L', '70', '74'),
#   ('UC-Davis', 'Sat, Dec 17, 2016', 'William Jessup', 'W', '87', '64'),
#   ('UC-Davis', 'Thu, Dec 22, 2016', 'Air Force', 'L', '67', '77'),
#   ('UC-Davis', 'Wed, Dec 28, 2016', 'Seattle', 'W', '72', '65'),
#   ('UC-Davis', 'Sat, Dec 31, 2016', 'Utah Valley', 'W', '83', '69'),
#   ('UC-Davis', 'Wed, Jan 4, 2017', 'UC-Santa Barbara', 'W', '73', '47'),
#   ('UC-Davis', 'Sat, Jan 7, 2017', 'Cal Poly', 'W', '68', '64'),
#   ('UC-Davis', 'Thu, Jan 12, 2017', 'UC-Riverside', 'L', '55', '61'),
#   ('UC-Davis', 'Sat, Jan 14, 2017', 'Cal State Northridge', 'W', '71', '68'),
#   ('UC-Davis', 'Sat, Jan 21, 2017', 'Hawaii', 'W', '76', '70'),
#   ('UC-Davis', 'Sat, Jan 28, 2017', 'UC-Irvine', 'W', '74', '65'),
#   ('UC-Davis', 'Thu, Feb 2, 2017', 'Cal Poly', 'L', '70', '74'),
#   ('UC-Davis', 'Sat, Feb 4, 2017', 'UC-Santa Barbara', 'W', '67', '64'),
#   ('UC-Davis', 'Wed, Feb 8, 2017', 'Cal State Fullerton', 'W', '74', '65'),
#   ('UC-Davis', 'Sat, Feb 11, 2017', 'UC-Riverside', 'W', '77', '63'),
#   ('UC-Davis', 'Thu, Feb 16, 2017', 'Long Beach State', 'L', '69', '78'),
#   ('UC-Davis', 'Sat, Feb 18, 2017', 'Cal State Fullerton', 'L', '72', '79'),
#   ('UC-Davis', 'Thu, Feb 23, 2017', 'Cal State Northridge', 'W', '96', '85'),
#   ('UC-Davis', 'Sat, Feb 25, 2017', 'Long Beach State', 'W', '75', '71'),
#   ('UC-Davis', 'Thu, Mar 2, 2017', 'Hawaii', 'W', '68', '59'),
#   ('UC-Davis', 'Sat, Mar 4, 2017', 'UC-Irvine', 'L', '49', '79'),
#   ('UC-Davis', 'Thu, Mar 9, 2017', 'Cal Poly', 'W', '66', '55'),
#   ('UC-Davis', 'Fri, Mar 10, 2017', 'Cal State Fullerton', 'W', '66', '64'),
#   ('UC-Davis', 'Sat, Mar 11, 2017', 'UC-Irvine', 'W', '50', '47'),
#   ('UC-Davis', 'Wed, Mar 15, 2017', 'North Carolina Central', 'W', '67', '63'),
#   ('UC-Davis', 'Fri, Mar 17, 2017', 'Kansas\xa0(3)', 'L', '62', '100')],
#  [('Miami (FL)', 'Fri, Nov 11, 2016', 'Western Carolina', 'W', '92', '43'),
#   ('Miami (FL)', 'Wed, Nov 16, 2016', 'North Florida', 'W', '94', '56'),
#   ('Miami (FL)', 'Sat, Nov 19, 2016', 'Pennsylvania', 'W', '74', '62'),
#   ('Miami (FL)', 'Thu, Nov 24, 2016', 'Stanford', 'W', '67', '53'),
#   ('Miami (FL)', 'Fri, Nov 25, 2016', 'Iowa State\xa0(21)', 'L', '56', '73'),
#   ('Miami (FL)', 'Sun, Nov 27, 2016', 'Florida', 'L', '56', '65'),
#   ('Miami (FL)', 'Wed, Nov 30, 2016', 'Rutgers', 'W', '73', '61'),
#   ('Miami (FL)', 'Sat, Dec 3, 2016', 'Wofford', 'W', '74', '57'),
#   ('Miami (FL)', 'Tue, Dec 6, 2016', 'South Carolina State', 'W', '82', '46'),
#   ('Miami (FL)', 'Fri, Dec 16, 2016', 'Florida Atlantic', 'W', '76', '56'),
#   ('Miami (FL)', 'Thu, Dec 22, 2016', 'George Washington', 'W', '72', '64'),
#   ('Miami (FL)', 'Wed, Dec 28, 2016', 'Columbia', 'W', '78', '67'),
#   ('Miami (FL)', 'Sat, Dec 31, 2016', 'North Carolina State', 'W', '81', '63'),
#   ('Miami (FL)', 'Wed, Jan 4, 2017', 'Syracuse', 'L', '55', '70'),
# ...
#  [('Florida State',
#    'Sat, Nov 12, 2016',
#    'Charleston Southern',
#    'W',
#    '88',
#    '67'),
#   ('Florida State', 'Tue, Nov 15, 2016', 'Iona', 'W', '99', '78'),
#   ('Florida State', 'Fri, Nov 18, 2016', 'Winthrop', 'W', '100', '86'),
#   ('Florida State', 'Sun, Nov 20, 2016', 'Detroit Mercy', 'W', '100', '71'),
#   ('Florida State', 'Thu, Nov 24, 2016', 'Temple', 'L', '86', '89'),
#   ('Florida State', 'Fri, Nov 25, 2016', 'Illinois', 'W', '72', '61'),
#   ('Florida State', 'Mon, Nov 28, 2016', 'Minnesota', 'W', '75', '67'),
#   ('Florida State', 'Sun, Dec 4, 2016', 'George Washington', 'W', '67', '48'),
#   ('Florida State',
#    'Tue, Dec 6, 2016',
#    'Southern Mississippi',
#    'W',
#    '98',
#    '49'),
#   ('Florida State', 'Thu, Dec 8, 2016', 'Nicholls State', 'W', '118', '63'),
#   ('Florida State', 'Sun, Dec 11, 2016', 'Florida\xa0(21)', 'W', '83', '78'),
#   ('Florida State', 'Sat, Dec 17, 2016', 'Manhattan', 'W', '83', '67'),
#   ('Florida State', 'Mon, Dec 19, 2016', 'Samford', 'W', '76', '68'),
#   ('Florida State', 'Wed, Dec 28, 2016', 'Wake Forest', 'W', '88', '72'),
#   ('Florida State', 'Sat, Dec 31, 2016', 'Virginia\xa0(12)', 'W', '60', '58'),
#   ('Florida State',
#    'Sat, Jan 7, 2017',
#    'Virginia Tech\xa0(21)',
#    'W',
#    '93',
#    '78'),
#   ('Florida State', 'Tue, Jan 10, 2017', 'Duke\xa0(7)', 'W', '88', '72'),
#   ('Florida State',
#    'Sat, Jan 14, 2017',
#    'North Carolina\xa0(11)',
#    'L',
#    '83',
#    '96'),
#   ('Florida State',
#    'Wed, Jan 18, 2017',
#    'Notre Dame\xa0(15)',
#    'W',
#    '83',
#    '80'),
#   ('Florida State',
#    'Sat, Jan 21, 2017',
#    'Louisville\xa0(12)',
#    'W',
#    '73',
#    '68'),
#   ('Florida State', 'Wed, Jan 25, 2017', 'Georgia Tech', 'L', '56', '78'),
#   ('Florida State', 'Sat, Jan 28, 2017', 'Syracuse', 'L', '72', '82'),
#   ('Florida State', 'Wed, Feb 1, 2017', 'Miami (FL)', 'W', '75', '57'),
#   ('Florida State', 'Sun, Feb 5, 2017', 'Clemson', 'W', '109', '61'),
#   ('Florida State',
#    'Wed, Feb 8, 2017',
#    'North Carolina State',
#    'W',
#    '95',
#    '71'),
#   ('Florida State', 'Sat, Feb 11, 2017', 'Notre Dame', 'L', '72', '84'),
#   ('Florida State', 'Sat, Feb 18, 2017', 'Pittsburgh', 'L', '66', '80'),
#   ('Florida State', 'Mon, Feb 20, 2017', 'Boston College', 'W', '104', '72'),
#   ('Florida State', 'Sat, Feb 25, 2017', 'Clemson', 'W', '76', '74'),
#   ('Florida State', 'Tue, Feb 28, 2017', 'Duke\xa0(17)', 'L', '70', '75'),
#   ('Florida State', 'Sat, Mar 4, 2017', 'Miami (FL)', 'W', '66', '57'),
#   ('Florida State', 'Thu, Mar 9, 2017', 'Virginia Tech', 'W', '74', '68'),
#   ('Florida State',
#    'Fri, Mar 10, 2017',
#    'Notre Dame\xa0(22)',
#    'L',
#    '73',
#    '77'),
#   ('Florida State',
#    'Thu, Mar 16, 2017',
#    'Florida Gulf Coast',
#    'W',
#    '86',
#    '80'),
#   ('Florida State', 'Sat, Mar 18, 2017', 'Xavier', 'L', '66', '91')],
#  [('Florida Gulf Coast', 'Fri, Nov 11, 2016', 'Florida', 'L', '59', '80'),
#   ('Florida Gulf Coast',
#    'Wed, Nov 16, 2016',
#    'Texas-Arlington',
#    'W',
#    '85',
#    '72'),
#   ('Florida Gulf Coast', 'Fri, Nov 18, 2016', 'Baylor', 'L', '72', '81'),
#   ('Florida Gulf Coast',
#    'Sun, Nov 20, 2016',
#    'Michigan State\xa0(13)',
#    'L',
#    '77',
#    '78'),
#   ('Florida Gulf Coast', 'Wed, Nov 23, 2016', 'Binghamton', 'W', '69', '53'),
#   ('Florida Gulf Coast',
#    'Fri, Nov 25, 2016',
#    'Long Beach State',
#    'W',
#    '68',
#    '67'),
#   ('Florida Gulf Coast', 'Tue, Nov 29, 2016', 'Ave Maria', 'W', '120', '60'),
#   ('Florida Gulf Coast',
#    'Sun, Dec 4, 2016',
#    'Georgia Southern',
#    'W',
#    '85',
#    '82'),
#   ('Florida Gulf Coast', 'Fri, Dec 9, 2016', 'Siena', 'W', '73', '69'),
#   ('Florida Gulf Coast',
#    'Sun, Dec 11, 2016',
#    'Florida International',
#    'W',
#    '82',
#    '63'),
#   ('Florida Gulf Coast',
#    'Tue, Dec 13, 2016',
#    'Georgia Southern',
#    'L',
#    '59',
#    '72'),
#   ('Florida Gulf Coast', 'Sat, Dec 17, 2016', 'La Salle', 'L', '80', '84'),
#   ('Florida Gulf Coast',
#    'Tue, Dec 20, 2016',
#    'Louisiana Tech',
#    'W',
#    '79',
#    '78'),
#   ('Florida Gulf Coast',
#    'Thu, Dec 22, 2016',
#    'Florida National University',
#    'W',
#    '107',
#    '50'),
#   ('Florida Gulf Coast',
#    'Wed, Dec 28, 2016',
#    'Florida Atlantic',
#    'W',
#    '75',
#    '62'),
#   ('Florida Gulf Coast',
#    'Sat, Dec 31, 2016',
#    'Florida Tech',
#    'W',
#    '101',
#    '49'),
#   ('Florida Gulf Coast', 'Sat, Jan 7, 2017', 'Stetson', 'W', '89', '88'),
#   ('Florida Gulf Coast',
#    'Thu, Jan 12, 2017',
#    'Kennesaw State',
#    'W',
#    '78',
#    '75'),
#   ('Florida Gulf Coast', 'Sat, Jan 14, 2017', 'Lipscomb', 'W', '84', '80'),
#   ('Florida Gulf Coast',
#    'Thu, Jan 19, 2017',
#    'South Carolina Upstate',
#    'L',
#    '60',
#    '62'),
#   ('Florida Gulf Coast', 'Sat, Jan 21, 2017', 'NJIT', 'W', '84', '71'),
#   ('Florida Gulf Coast',
#    'Wed, Jan 25, 2017',
#    'North Florida',
#    'W',
#    '86',
#    '82'),
#   ('Florida Gulf Coast', 'Sat, Jan 28, 2017', 'Jacksonville', 'W', '78', '56'),
#   ('Florida Gulf Coast',
#    'Mon, Jan 30, 2017',
#    'North Florida',
#    'W',
#    '74',
#    '59'),
#   ('Florida Gulf Coast', 'Sat, Feb 4, 2017', 'Jacksonville', 'W', '67', '57'),
#   ('Florida Gulf Coast', 'Thu, Feb 9, 2017', 'Lipscomb', 'L', '60', '65'),
#   ('Florida Gulf Coast',
#    'Sat, Feb 11, 2017',
#    'Kennesaw State',
#    'W',
#    '75',
#    '63'),
#   ('Florida Gulf Coast', 'Thu, Feb 16, 2017', 'NJIT', 'W', '80', '73'),
#   ('Florida Gulf Coast',
#    'Sat, Feb 18, 2017',
#    'South Carolina Upstate',
#    'W',
#    '97',
#    '89'),
#   ('Florida Gulf Coast', 'Thu, Feb 23, 2017', 'Stetson', 'W', '80', '70'),
#   ('Florida Gulf Coast', 'Mon, Feb 27, 2017', 'Stetson', 'W', '87', '57'),
#   ('Florida Gulf Coast',
#    'Thu, Mar 2, 2017',
#    'Kennesaw State',
#    'W',
#    '74',
#    '62'),
#   ('Florida Gulf Coast', 'Sun, Mar 5, 2017', 'North Florida', 'W', '77', '61'),
#   ('Florida Gulf Coast',
#    'Thu, Mar 16, 2017',
#    'Florida State\xa0(16)',
#    'L',
#    '80',
#    '86')],
#  [("Saint Mary's (CA)", 'Fri, Nov 11, 2016', 'Nevada', 'W', '81', '63'),
#   ("Saint Mary's (CA)", 'Wed, Nov 16, 2016', 'Prairie View', 'W', '110', '72'),
#   ("Saint Mary's (CA)", 'Sat, Nov 19, 2016', 'Dayton', 'W', '61', '57'),
#   ("Saint Mary's (CA)",
#    'Tue, Nov 22, 2016',
#    'San Jose State',
#    'W',
#    '81',
#    '64'),
#   ("Saint Mary's (CA)",
#    'Sun, Nov 27, 2016',
#    'Alabama-Birmingham',
#    'W',
#    '76',
#    '63'),
#   ("Saint Mary's (CA)", 'Wed, Nov 30, 2016', 'Stanford', 'W', '66', '51'),
#   ("Saint Mary's (CA)",
#    'Thu, Dec 8, 2016',
#    'Texas-Arlington',
#    'L',
#    '51',
#    '65'),
#   ("Saint Mary's (CA)", 'Sun, Dec 11, 2016', 'UC-Irvine', 'W', '84', '53'),
#   ("Saint Mary's (CA)",
#    'Wed, Dec 14, 2016',
#    'Western Kentucky',
#    'W',
#    '73',
#    '51'),
#   ("Saint Mary's (CA)",
#    'Tue, Dec 20, 2016',
#    'Texas A&M-Corpus Christi',
#    'W',
#    '67',
#    '46'),
#   ("Saint Mary's (CA)",
#    'Thu, Dec 22, 2016',
#    'South Carolina State',
#    'W',
#    '74',
#    '47'),
#   ("Saint Mary's (CA)",
#    'Thu, Dec 29, 2016',
#    'Loyola Marymount',
#    'W',
#    '72',
#    '60'),
#   ("Saint Mary's (CA)", 'Sat, Dec 31, 2016', 'San Diego', 'W', '72', '60'),
#   ("Saint Mary's (CA)", 'Thu, Jan 5, 2017', 'Brigham Young', 'W', '81', '68'),
#   ("Saint Mary's (CA)", 'Sat, Jan 7, 2017', 'San Francisco', 'W', '63', '52'),
#   ("Saint Mary's (CA)", 'Thu, Jan 12, 2017', 'Portland', 'W', '74', '33'),
#   ("Saint Mary's (CA)",
#    'Sat, Jan 14, 2017',
#    'Gonzaga\xa0(5)',
#    'L',
#    '56',
#    '79'),
#   ("Saint Mary's (CA)", 'Thu, Jan 19, 2017', 'Pacific', 'W', '62', '50'),
#   ("Saint Mary's (CA)", 'Sat, Jan 21, 2017', 'Pepperdine', 'W', '85', '65'),
#   ("Saint Mary's (CA)", 'Thu, Jan 26, 2017', 'San Francisco', 'W', '66', '46'),
#   ("Saint Mary's (CA)", 'Sat, Jan 28, 2017', 'Santa Clara', 'W', '72', '59'),
#   ("Saint Mary's (CA)", 'Thu, Feb 2, 2017', 'Pacific', 'W', '74', '70'),
#   ("Saint Mary's (CA)", 'Sat, Feb 4, 2017', 'San Diego', 'W', '71', '27'),
#   ("Saint Mary's (CA)", 'Thu, Feb 9, 2017', 'Portland', 'W', '51', '41'),
#   ("Saint Mary's (CA)",
#    'Sat, Feb 11, 2017',
#    'Gonzaga\xa0(1)',
#    'L',
#    '64',
#    '74'),
#   ("Saint Mary's (CA)",
#    'Thu, Feb 16, 2017',
#    'Loyola Marymount',
#    'W',
#    '81',
#    '48'),
#   ("Saint Mary's (CA)", 'Sat, Feb 18, 2017', 'Brigham Young', 'W', '70', '57'),
#   ("Saint Mary's (CA)", 'Thu, Feb 23, 2017', 'Pepperdine', 'W', '78', '49'),
#   ("Saint Mary's (CA)", 'Sat, Feb 25, 2017', 'Santa Clara', 'W', '70', '56'),
#   ("Saint Mary's (CA)", 'Sat, Mar 4, 2017', 'Portland', 'W', '81', '58'),
#   ("Saint Mary's (CA)", 'Mon, Mar 6, 2017', 'Brigham Young', 'W', '81', '50'),
#   ("Saint Mary's (CA)", 'Tue, Mar 7, 2017', 'Gonzaga\xa0(4)', 'L', '56', '74'),
#   ("Saint Mary's (CA)",
#    'Thu, Mar 16, 2017',
#    'Virginia Commonwealth',
#    'W',
#    '85',
#    '77'),
#   ("Saint Mary's (CA)",
#    'Sat, Mar 18, 2017',
#    'Arizona\xa0(4)',
#    'L',
#    '60',
#    '69')],
#  [('VCU', 'Fri, Nov 11, 2016', 'North Carolina-Asheville', 'W', '80', '65'),
#   ('VCU', 'Tue, Nov 15, 2016', 'Liberty', 'W', '64', '59'),
#   ('VCU', 'Fri, Nov 18, 2016', 'Binghamton', 'W', '81', '42'),
#   ('VCU', 'Wed, Nov 23, 2016', 'Baylor\xa0(20)', 'L', '63', '71'),
#   ('VCU', 'Thu, Nov 24, 2016', "St. John's (NY)", 'W', '75', '69'),
#   ('VCU', 'Fri, Nov 25, 2016', 'Louisiana State', 'W', '85', '74'),
#   ('VCU', 'Tue, Nov 29, 2016', 'Princeton', 'W', '81', '70'),
#   ('VCU', 'Sat, Dec 3, 2016', 'Illinois', 'L', '46', '64'),
#   ('VCU', 'Wed, Dec 7, 2016', 'Georgia Tech', 'L', '73', '76'),
#   ('VCU', 'Sat, Dec 10, 2016', 'Old Dominion', 'W', '67', '64'),
#   ('VCU', 'Sat, Dec 17, 2016', 'Middle Tennessee', 'W', '80', '77'),
#   ('VCU', 'Thu, Dec 22, 2016', 'Louisiana-Monroe', 'W', '78', '65'),
#   ('VCU', 'Tue, Dec 27, 2016', 'Howard', 'W', '85', '51'),
#   ('VCU', 'Fri, Dec 30, 2016', 'George Mason', 'W', '73', '64'),
#   ('VCU', 'Wed, Jan 4, 2017', 'Duquesne', 'W', '94', '87'),
#   ('VCU', 'Sat, Jan 7, 2017', 'Massachusetts', 'W', '81', '64'),
#   ('VCU', 'Wed, Jan 11, 2017', 'George Washington', 'W', '85', '55'),
#   ('VCU', 'Sat, Jan 14, 2017', 'Davidson', 'L', '63', '69'),
#   ('VCU', 'Wed, Jan 18, 2017', 'Fordham', 'L', '67', '69'),
#   ('VCU', 'Sun, Jan 22, 2017', 'La Salle', 'W', '90', '52'),
#   ('VCU', 'Fri, Jan 27, 2017', 'Dayton', 'W', '73', '68'),
#   ('VCU', 'Wed, Feb 1, 2017', 'Richmond', 'W', '81', '74'),
#   ('VCU', 'Sat, Feb 4, 2017', 'St. Bonaventure', 'W', '83', '77'),
#   ('VCU', 'Wed, Feb 8, 2017', 'George Washington', 'W', '54', '53'),
#   ('VCU', 'Sat, Feb 11, 2017', 'Davidson', 'W', '74', '60'),
#   ('VCU', 'Tue, Feb 14, 2017', "Saint Joseph's", 'W', '91', '81'),
#   ('VCU', 'Fri, Feb 17, 2017', 'Richmond', 'W', '84', '73'),
#   ('VCU', 'Wed, Feb 22, 2017', 'Saint Louis', 'W', '64', '50'),
#   ('VCU', 'Sat, Feb 25, 2017', 'Rhode Island', 'L', '59', '69'),
#   ('VCU', 'Wed, Mar 1, 2017', 'Dayton', 'L', '72', '79'),
#   ('VCU', 'Sat, Mar 4, 2017', 'George Mason', 'W', '72', '60'),
#   ('VCU', 'Fri, Mar 10, 2017', 'George Mason', 'W', '71', '60'),
#   ('VCU', 'Sat, Mar 11, 2017', 'Richmond', 'W', '87', '77'),
#   ('VCU', 'Sun, Mar 12, 2017', 'Rhode Island', 'L', '63', '70'),
#   ('VCU', 'Thu, Mar 16, 2017', "Saint Mary's (CA)\xa0(22)", 'L', '77', '85')],
#  [('Arizona', 'Fri, Nov 11, 2016', 'Michigan State\xa0(12)', 'W', '65', '63'),
#   ('Arizona', 'Tue, Nov 15, 2016', 'Cal State Bakersfield', 'W', '78', '66'),
#   ('Arizona', 'Fri, Nov 18, 2016', 'Sacred Heart', 'W', '95', '65'),
#   ('Arizona', 'Mon, Nov 21, 2016', 'Northern Colorado', 'W', '71', '55'),
#   ('Arizona', 'Thu, Nov 24, 2016', 'Santa Clara', 'W', '69', '61'),
#   ('Arizona', 'Fri, Nov 25, 2016', 'Butler', 'L', '65', '69'),
#   ('Arizona', 'Wed, Nov 30, 2016', 'Texas Southern', 'W', '85', '63'),
#   ('Arizona', 'Sat, Dec 3, 2016', 'Gonzaga\xa0(8)', 'L', '62', '69'),
#   ('Arizona', 'Tue, Dec 6, 2016', 'UC-Irvine', 'W', '79', '57'),
#   ('Arizona', 'Sat, Dec 10, 2016', 'Missouri', 'W', '79', '60'),
#   ('Arizona', 'Wed, Dec 14, 2016', 'Grand Canyon', 'W', '64', '54'),
#   ('Arizona', 'Sat, Dec 17, 2016', 'Texas A&M', 'W', '67', '63'),
#   ('Arizona', 'Tue, Dec 20, 2016', 'New Mexico', 'W', '77', '46'),
#   ('Arizona',
#    'Fri, Dec 30, 2016',
#    'University of California',
#    'W',
#    '67',
#    '62'),
#   ('Arizona', 'Sun, Jan 1, 2017', 'Stanford', 'W', '91', '52'),
#   ('Arizona', 'Thu, Jan 5, 2017', 'Utah', 'W', '66', '56'),
#   ('Arizona', 'Sat, Jan 7, 2017', 'Colorado', 'W', '82', '73'),
#   ('Arizona', 'Thu, Jan 12, 2017', 'Arizona State', 'W', '91', '75'),
#   ('Arizona', 'Thu, Jan 19, 2017', 'Southern California', 'W', '73', '66'),
#   ('Arizona', 'Sat, Jan 21, 2017', 'UCLA\xa0(3)', 'W', '96', '85'),
#   ('Arizona', 'Thu, Jan 26, 2017', 'Washington State', 'W', '79', '62'),
#   ('Arizona', 'Sun, Jan 29, 2017', 'Washington', 'W', '77', '66'),
#   ('Arizona', 'Thu, Feb 2, 2017', 'Oregon State', 'W', '71', '54'),
#   ('Arizona', 'Sat, Feb 4, 2017', 'Oregon\xa0(13)', 'L', '58', '85'),
#   ('Arizona', 'Wed, Feb 8, 2017', 'Stanford', 'W', '74', '67'),
#   ('Arizona',
#    'Sat, Feb 11, 2017',
#    'University of California',
#    'W',
#    '62',
#    '57'),
#   ('Arizona', 'Thu, Feb 16, 2017', 'Washington State', 'W', '78', '59'),
#   ('Arizona', 'Sat, Feb 18, 2017', 'Washington', 'W', '76', '68'),
#   ('Arizona', 'Thu, Feb 23, 2017', 'Southern California', 'W', '90', '77'),
#   ('Arizona', 'Sat, Feb 25, 2017', 'UCLA\xa0(5)', 'L', '72', '77'),
#   ('Arizona', 'Sat, Mar 4, 2017', 'Arizona State', 'W', '73', '60'),
#   ('Arizona', 'Thu, Mar 9, 2017', 'Colorado', 'W', '92', '78'),
#   ('Arizona', 'Fri, Mar 10, 2017', 'UCLA\xa0(3)', 'W', '86', '75'),
#   ('Arizona', 'Sat, Mar 11, 2017', 'Oregon\xa0(5)', 'W', '83', '80'),
#   ('Arizona', 'Thu, Mar 16, 2017', 'North Dakota', 'W', '100', '82'),
#   ('Arizona',
#    'Sat, Mar 18, 2017',
#    "Saint Mary's (CA)\xa0(22)",
#    'W',
#    '69',
#    '60'),
#   ('Arizona', 'Thu, Mar 23, 2017', 'Xavier', 'L', '71', '73')],
#  [('North Dakota', 'Fri, Nov 11, 2016', 'Crown College', 'W', '98', '48'),
#   ('North Dakota', 'Tue, Nov 15, 2016', 'Mayville State', 'W', '94', '66'),
#   ('North Dakota',
#    'Sun, Nov 20, 2016',
#    'Presentation College',
#    'W',
#    '101',
#    '63'),
#   ('North Dakota', 'Fri, Nov 25, 2016', 'North Florida', 'L', '75', '76'),
#   ('North Dakota', 'Sat, Nov 26, 2016', 'Wright State', 'L', '79', '83'),
#   ('North Dakota',
#    'Sun, Nov 27, 2016',
#    'Cal State Bakersfield',
#    'W',
#    '57',
#    '55'),
#   ('North Dakota', 'Wed, Dec 7, 2016', 'North Dakota State', 'W', '74', '56'),
#   ('North Dakota', 'Sat, Dec 10, 2016', 'Northern Iowa', 'L', '70', '78'),
#   ('North Dakota', 'Fri, Dec 16, 2016', 'North Dakota State', 'L', '70', '87'),
#   ('North Dakota', 'Tue, Dec 20, 2016', 'Iowa', 'L', '73', '84'),
#   ('North Dakota', 'Thu, Dec 29, 2016', 'Portland State', 'L', '62', '99'),
#   ('North Dakota', 'Sat, Dec 31, 2016', 'Sacramento State', 'W', '90', '82'),
#   ('North Dakota', 'Thu, Jan 5, 2017', 'Northern Arizona', 'W', '68', '63'),
#   ('North Dakota', 'Sat, Jan 7, 2017', 'Southern Utah', 'W', '95', '65'),
#   ('North Dakota', 'Thu, Jan 12, 2017', 'Montana State', 'W', '90', '85'),
#   ('North Dakota', 'Sat, Jan 14, 2017', 'Montana', 'L', '70', '76'),
#   ('North Dakota', 'Thu, Jan 19, 2017', 'Weber State', 'W', '83', '77'),
#   ('North Dakota', 'Sat, Jan 21, 2017', 'Idaho State', 'W', '89', '64'),
#   ('North Dakota', 'Thu, Jan 26, 2017', 'Southern Utah', 'W', '91', '89'),
#   ('North Dakota', 'Sat, Jan 28, 2017', 'Northern Arizona', 'L', '67', '68'),
#   ('North Dakota', 'Sat, Feb 4, 2017', 'Northern Colorado', 'W', '87', '77'),
#   ('North Dakota', 'Thu, Feb 9, 2017', 'Eastern Washington', 'W', '95', '86'),
#   ('North Dakota', 'Sat, Feb 11, 2017', 'Idaho', 'W', '88', '65'),
#   ('North Dakota', 'Thu, Feb 16, 2017', 'Idaho State', 'W', '77', '61'),
#   ('North Dakota', 'Sat, Feb 18, 2017', 'Weber State', 'W', '77', '68'),
#   ('North Dakota', 'Sat, Feb 25, 2017', 'Northern Colorado', 'W', '84', '81'),
#   ('North Dakota', 'Thu, Mar 2, 2017', 'Sacramento State', 'L', '53', '57'),
#   ('North Dakota', 'Sat, Mar 4, 2017', 'Portland State', 'W', '82', '73'),
#   ('North Dakota', 'Thu, Mar 9, 2017', 'Portland State', 'W', '95', '72'),
#   ('North Dakota', 'Fri, Mar 10, 2017', 'Idaho', 'W', '69', '64'),
#   ('North Dakota', 'Sat, Mar 11, 2017', 'Weber State', 'W', '93', '89'),
#   ('North Dakota', 'Thu, Mar 16, 2017', 'Arizona\xa0(4)', 'L', '82', '100')]]

# %%
reduced_results = list()
for team in all_teams:
    for result in team:
        if 'W' in result:
            reduced_results.append(result)
            

        
len(all_teams), len(reduced_results)
# Out:
# (64, 1646)

# %%
tournament_results = list()
for result in reduced_results:
    if result[2] in tournament_teams:
        tournament_results.append(result)
tournament_results
# Out:
# [('Villanova', 'Sat, Jan 7, 2017', 'Marquette', 'W', '93', '81'),
#  ('Villanova', 'Mon, Jan 16, 2017', 'Seton Hall', 'W', '76', '46'),
#  ('Villanova', 'Sat, Feb 18, 2017', 'Seton Hall', 'W', '92', '70'),
#  ('Villanova', 'Fri, Mar 10, 2017', 'Seton Hall', 'W', '55', '53'),
#  ('Villanova', 'Sat, Mar 11, 2017', 'Creighton', 'W', '74', '60'),
#  ('Villanova', 'Thu, Mar 16, 2017', "Mount St. Mary's", 'W', '76', '56'),
#  ('Wisconsin', 'Sat, Dec 10, 2016', 'Marquette', 'W', '93', '84'),
#  ('Wisconsin', 'Tue, Jan 17, 2017', 'Michigan', 'W', '68', '64'),
#  ('Wisconsin', 'Sat, Jan 21, 2017', 'Minnesota', 'W', '78', '76'),
#  ('Wisconsin', 'Sun, Mar 5, 2017', 'Minnesota', 'W', '66', '49'),
#  ('Wisconsin', 'Sat, Mar 11, 2017', 'Northwestern', 'W', '76', '48'),
#  ('Wisconsin', 'Thu, Mar 16, 2017', 'Virginia Tech', 'W', '84', '74'),
#  ('Virginia Tech', 'Wed, Nov 30, 2016', 'Michigan', 'W', '73', '70'),
#  ('Virginia Tech', 'Mon, Feb 27, 2017', 'Miami (FL)', 'W', '66', '61'),
#  ('Virginia', 'Wed, Feb 1, 2017', 'Virginia Tech', 'W', '71', '48'),
#  ('Virginia',
#   'Thu, Mar 16, 2017',
#   'North Carolina-Wilmington',
#   'W',
#   '76',
#   '71'),
#  ('Florida', 'Fri, Nov 11, 2016', 'Florida Gulf Coast', 'W', '80', '59'),
#  ('Florida', 'Thu, Nov 24, 2016', 'Seton Hall', 'W', '81', '76'),
#  ('Florida', 'Sun, Nov 27, 2016', 'Miami (FL)', 'W', '65', '56'),
#  ('Florida', 'Thu, Dec 29, 2016', 'Arkansas', 'W', '81', '72'),
#  ('Florida', 'Tue, Feb 21, 2017', 'South Carolina', 'W', '81', '66'),
#  ('Florida', 'Wed, Mar 1, 2017', 'Arkansas', 'W', '78', '65'),
#  ('ETSU', 'Sat, Nov 26, 2016', 'South Dakota State', 'W', '71', '59'),
#  ('USC', 'Sat, Dec 17, 2016', 'Troy', 'W', '82', '77'),
#  ('Baylor', 'Fri, Nov 18, 2016', 'Florida Gulf Coast', 'W', '81', '72'),
#  ('Baylor', 'Wed, Dec 21, 2016', 'Texas Southern', 'W', '89', '63'),
#  ('Baylor', 'Wed, Jan 4, 2017', 'Iowa State', 'W', '65', '63'),
#  ('Baylor', 'Sat, Jan 7, 2017', 'Oklahoma State', 'W', '61', '57'),
#  ('Baylor', 'Wed, Feb 8, 2017', 'Oklahoma State', 'W', '72', '69'),
#  ('Baylor', 'Fri, Mar 17, 2017', 'New Mexico State', 'W', '91', '73'),
#  ('South Carolina', 'Thu, Dec 1, 2016', 'Vermont', 'W', '68', '50'),
#  ('South Carolina', 'Fri, Mar 17, 2017', 'Marquette', 'W', '93', '73'),
#  ('Marquette', 'Fri, Nov 11, 2016', 'Vanderbilt', 'W', '95', '71'),
#  ('Marquette', 'Wed, Jan 11, 2017', 'Seton Hall', 'W', '89', '86'),
#  ('Marquette', 'Sat, Feb 18, 2017', 'Xavier', 'W', '83', '61'),
#  ('Marquette', 'Wed, Mar 1, 2017', 'Xavier', 'W', '95', '84'),
#  ('Marquette', 'Sat, Mar 4, 2017', 'Creighton', 'W', '91', '83'),
#  ('Duke', 'Tue, Nov 29, 2016', 'Michigan State', 'W', '78', '69'),
#  ('Duke', 'Sat, Jan 21, 2017', 'Miami (FL)', 'W', '70', '58'),
#  ('Duke', 'Fri, Mar 17, 2017', 'Troy', 'W', '87', '65'),
#  ('Kansas', 'Tue, Jan 3, 2017', 'Kansas State', 'W', '90', '88'),
#  ('Kansas', 'Sat, Jan 14, 2017', 'Oklahoma State', 'W', '87', '80'),
#  ('Kansas', 'Mon, Jan 16, 2017', 'Iowa State', 'W', '76', '72'),
#  ('Kansas', 'Mon, Feb 6, 2017', 'Kansas State', 'W', '74', '71'),
#  ('Kansas', 'Sat, Mar 4, 2017', 'Oklahoma State', 'W', '90', '85'),
#  ('Kansas', 'Fri, Mar 17, 2017', 'UC-Davis', 'W', '100', '62'),
#  ('Kansas', 'Sun, Mar 19, 2017', 'Michigan State', 'W', '90', '70'),
#  ('Miami (FL)', 'Wed, Feb 8, 2017', 'Virginia Tech', 'W', '74', '68'),
#  ('Michigan State',
#   'Sun, Nov 20, 2016',
#   'Florida Gulf Coast',
#   'W',
#   '78',
#   '77'),
#  ('Michigan State', 'Fri, Nov 25, 2016', 'Wichita State', 'W', '77', '72'),
#  ('Michigan State', 'Tue, Dec 27, 2016', 'Minnesota', 'W', '75', '74'),
#  ('Michigan State', 'Fri, Dec 30, 2016', 'Northwestern', 'W', '61', '52'),
#  ('Michigan State', 'Sun, Jan 29, 2017', 'Michigan', 'W', '70', '62'),
#  ('Michigan State', 'Fri, Mar 17, 2017', 'Miami (FL)', 'W', '78', '58'),
#  ('Iowa State', 'Mon, Nov 14, 2016', "Mount St. Mary's", 'W', '73', '55'),
#  ('Iowa State', 'Fri, Nov 25, 2016', 'Miami (FL)', 'W', '73', '56'),
#  ('Iowa State', 'Wed, Jan 11, 2017', 'Oklahoma State', 'W', '96', '86'),
#  ('Iowa State', 'Tue, Jan 24, 2017', 'Kansas State', 'W', '70', '65'),
#  ('Iowa State', 'Wed, Feb 15, 2017', 'Kansas State', 'W', '87', '79'),
#  ('Iowa State', 'Tue, Feb 28, 2017', 'Oklahoma State', 'W', '86', '83'),
#  ('Iowa State', 'Thu, Mar 9, 2017', 'Oklahoma State', 'W', '92', '83'),
#  ('Iowa State', 'Thu, Mar 16, 2017', 'Nevada', 'W', '84', '73'),
#  ('Nevada', 'Sun, Nov 20, 2016', 'Iona', 'W', '91', '76'),
#  ('Purdue', 'Tue, Jan 24, 2017', 'Michigan State', 'W', '84', '73'),
#  ('Purdue', 'Sat, Feb 18, 2017', 'Michigan State', 'W', '80', '63'),
#  ('Purdue', 'Sun, Mar 5, 2017', 'Northwestern', 'W', '69', '65'),
#  ('Purdue', 'Thu, Mar 16, 2017', 'Vermont', 'W', '80', '70'),
#  ('Creighton', 'Wed, Dec 28, 2016', 'Seton Hall', 'W', '89', '75'),
#  ('Creighton', 'Fri, Mar 10, 2017', 'Xavier', 'W', '75', '72'),
#  ('Rhode Island', 'Fri, Mar 17, 2017', 'Creighton', 'W', '84', '72'),
#  ('Oregon', 'Fri, Mar 17, 2017', 'Iona', 'W', '93', '77'),
#  ('Oregon', 'Sun, Mar 19, 2017', 'Rhode Island', 'W', '75', '72'),
#  ('Iona', 'Sat, Nov 26, 2016', 'Nevada', 'W', '75', '73'),
#  ('Michigan', 'Thu, Nov 17, 2016', 'Marquette', 'W', '79', '61'),
#  ('Michigan', 'Sat, Nov 26, 2016', "Mount St. Mary's", 'W', '64', '47'),
#  ('Michigan', 'Tue, Feb 7, 2017', 'Michigan State', 'W', '86', '57'),
#  ('Michigan', 'Sat, Mar 11, 2017', 'Minnesota', 'W', '84', '77'),
#  ('Michigan', 'Fri, Mar 17, 2017', 'Oklahoma State', 'W', '92', '91'),
#  ('Oklahoma State', 'Sat, Dec 17, 2016', 'Wichita State', 'W', '93', '76'),
#  ('Oklahoma State', 'Sat, Jan 28, 2017', 'Arkansas', 'W', '99', '71'),
#  ('Oklahoma State', 'Wed, Feb 22, 2017', 'Kansas State', 'W', '80', '68'),
#  ('Louisville', 'Thu, Nov 24, 2016', 'Wichita State', 'W', '62', '52'),
#  ('Louisville', 'Sat, Dec 10, 2016', 'Texas Southern', 'W', '102', '71'),
#  ('Louisville', 'Sat, Feb 11, 2017', 'Miami (FL)', 'W', '71', '66'),
#  ('Louisville', 'Sat, Feb 18, 2017', 'Virginia Tech', 'W', '94', '90'),
#  ('Louisville', 'Fri, Mar 17, 2017', 'Jacksonville State', 'W', '78', '63'),
#  ('UNC', 'Tue, Nov 22, 2016', 'Oklahoma State', 'W', '107', '75'),
#  ('UNC', 'Thu, Jan 26, 2017', 'Virginia Tech', 'W', '91', '72'),
#  ('UNC', 'Thu, Mar 9, 2017', 'Miami (FL)', 'W', '78', '53'),
#  ('UNC', 'Fri, Mar 17, 2017', 'Texas Southern', 'W', '103', '64'),
#  ('UNC', 'Sun, Mar 19, 2017', 'Arkansas', 'W', '72', '65'),
#  ('Arkansas', 'Mon, Nov 28, 2016', "Mount St. Mary's", 'W', '89', '76'),
#  ('Arkansas', 'Tue, Jan 24, 2017', 'Vanderbilt', 'W', '71', '70'),
#  ('Arkansas', 'Sat, Mar 11, 2017', 'Vanderbilt', 'W', '76', '62'),
#  ('Arkansas', 'Fri, Mar 17, 2017', 'Seton Hall', 'W', '77', '71'),
#  ('Seton Hall', 'Sun, Jan 1, 2017', 'Marquette', 'W', '69', '66'),
#  ('Seton Hall', 'Wed, Feb 22, 2017', 'Xavier', 'W', '71', '64'),
#  ('Seton Hall', 'Thu, Mar 9, 2017', 'Marquette', 'W', '82', '76'),
#  ('Minnesota', 'Wed, Nov 16, 2016', "Mount St. Mary's", 'W', '80', '56'),
#  ('Minnesota', 'Tue, Nov 22, 2016', 'Arkansas', 'W', '85', '71'),
#  ('Minnesota', 'Sat, Dec 3, 2016', 'Vanderbilt', 'W', '56', '52'),
#  ('Minnesota', 'Thu, Jan 5, 2017', 'Northwestern', 'W', '70', '66'),
#  ('Minnesota', 'Sun, Feb 19, 2017', 'Michigan', 'W', '83', '78'),
#  ('Minnesota', 'Fri, Mar 10, 2017', 'Michigan State', 'W', '63', '58'),
#  ('Middle Tennessee',
#   'Fri, Nov 25, 2016',
#   'North Carolina-Wilmington',
#   'W',
#   '68',
#   '63'),
#  ('Middle Tennessee', 'Thu, Dec 8, 2016', 'Vanderbilt', 'W', '71', '48'),
#  ('Middle Tennessee', 'Thu, Mar 16, 2017', 'Minnesota', 'W', '81', '72'),
#  ('Butler', 'Wed, Nov 16, 2016', 'Northwestern', 'W', '70', '68'),
#  ('Butler', 'Sat, Nov 19, 2016', 'Bucknell', 'W', '86', '60'),
#  ('Butler', 'Thu, Nov 24, 2016', 'Vanderbilt', 'W', '76', '66'),
#  ('Butler', 'Wed, Dec 21, 2016', 'Vermont', 'W', '81', '69'),
#  ('Butler', 'Mon, Jan 16, 2017', 'Marquette', 'W', '88', '80'),
#  ('Butler', 'Wed, Jan 25, 2017', 'Seton Hall', 'W', '61', '54'),
#  ('Butler', 'Tue, Feb 7, 2017', 'Marquette', 'W', '68', '65'),
#  ('Butler', 'Sun, Feb 26, 2017', 'Xavier', 'W', '88', '79'),
#  ('Butler', 'Thu, Mar 16, 2017', 'Winthrop', 'W', '76', '64'),
#  ('Butler', 'Sat, Mar 18, 2017', 'Middle Tennessee', 'W', '74', '65'),
#  ('Cincinnati', 'Tue, Dec 13, 2016', 'Texas Southern', 'W', '96', '58'),
#  ('Cincinnati', 'Fri, Mar 17, 2017', 'Kansas State', 'W', '75', '61'),
#  ('Kansas State', 'Wed, Jan 18, 2017', 'Oklahoma State', 'W', '96', '88'),
#  ('UCLA', 'Sat, Dec 10, 2016', 'Michigan', 'W', '102', '84'),
#  ('UCLA', 'Fri, Mar 17, 2017', 'Kent State', 'W', '97', '80'),
#  ('Dayton', 'Sat, Dec 3, 2016', 'Winthrop', 'W', '83', '67'),
#  ('Dayton', 'Wed, Dec 21, 2016', 'Vanderbilt', 'W', '68', '63'),
#  ('Dayton', 'Fri, Jan 6, 2017', 'Rhode Island', 'W', '67', '64'),
#  ('Dayton', 'Fri, Feb 10, 2017', 'Rhode Island', 'W', '75', '74'),
#  ('Wichita State', 'Thu, Dec 22, 2016', 'South Dakota State', 'W', '89', '67'),
#  ('Wichita State', 'Fri, Mar 17, 2017', 'Dayton', 'W', '64', '58'),
#  ('Kentucky', 'Sat, Jan 7, 2017', 'Arkansas', 'W', '97', '71'),
#  ('Kentucky', 'Tue, Jan 10, 2017', 'Vanderbilt', 'W', '87', '81'),
#  ('Kentucky', 'Tue, Feb 28, 2017', 'Vanderbilt', 'W', '73', '67'),
#  ('Kentucky', 'Sun, Mar 12, 2017', 'Arkansas', 'W', '82', '65'),
#  ('Kentucky', 'Fri, Mar 17, 2017', 'Northern Kentucky', 'W', '79', '70'),
#  ('Gonzaga', 'Fri, Nov 25, 2016', 'Florida', 'W', '77', '72'),
#  ('Gonzaga', 'Thu, Mar 16, 2017', 'South Dakota State', 'W', '66', '46'),
#  ('Gonzaga', 'Sat, Mar 18, 2017', 'Northwestern', 'W', '79', '73'),
#  ('Gonzaga', 'Sat, Mar 25, 2017', 'Xavier', 'W', '83', '59'),
#  ('Gonzaga', 'Sat, Apr 1, 2017', 'South Carolina', 'W', '77', '73'),
#  ('Northwestern', 'Sat, Dec 17, 2016', 'Dayton', 'W', '67', '64'),
#  ('Northwestern', 'Wed, Mar 1, 2017', 'Michigan', 'W', '67', '65'),
#  ('Northwestern', 'Thu, Mar 16, 2017', 'Vanderbilt', 'W', '68', '66'),
#  ('Vanderbilt', 'Sat, Jan 28, 2017', 'Iowa State', 'W', '84', '78'),
#  ('Vanderbilt', 'Tue, Feb 7, 2017', 'Arkansas', 'W', '72', '59'),
#  ('Notre Dame', 'Tue, Nov 22, 2016', 'Northwestern', 'W', '70', '66'),
#  ('Notre Dame', 'Thu, Jan 12, 2017', 'Miami (FL)', 'W', '67', '62'),
#  ('Notre Dame', 'Sat, Jan 14, 2017', 'Virginia Tech', 'W', '76', '71'),
#  ('Notre Dame', 'Thu, Mar 16, 2017', 'Princeton', 'W', '60', '58'),
#  ('Princeton', 'Thu, Dec 22, 2016', 'Bucknell', 'W', '72', '70'),
#  ('West Virginia', 'Fri, Nov 11, 2016', "Mount St. Mary's", 'W', '87', '59'),
#  ('West Virginia', 'Fri, Dec 23, 2016', 'Northern Kentucky', 'W', '92', '61'),
#  ('West Virginia', 'Fri, Dec 30, 2016', 'Oklahoma State', 'W', '92', '75'),
#  ('West Virginia', 'Tue, Jan 31, 2017', 'Iowa State', 'W', '85', '72'),
#  ('West Virginia', 'Sat, Feb 11, 2017', 'Kansas State', 'W', '85', '66'),
#  ('West Virginia', 'Fri, Mar 10, 2017', 'Kansas State', 'W', '51', '50'),
#  ('West Virginia', 'Thu, Mar 16, 2017', 'Bucknell', 'W', '86', '80'),
#  ('Bucknell', 'Mon, Nov 21, 2016', 'Vanderbilt', 'W', '75', '72'),
#  ('Bucknell', 'Mon, Dec 19, 2016', "Mount St. Mary's", 'W', '81', '65'),
#  ('Maryland', 'Sat, Nov 26, 2016', 'Kansas State', 'W', '69', '68'),
#  ('Maryland', 'Sat, Dec 3, 2016', 'Oklahoma State', 'W', '71', '70'),
#  ('Maryland', 'Mon, Dec 12, 2016', 'Jacksonville State', 'W', '92', '66'),
#  ('Maryland', 'Sat, Jan 7, 2017', 'Michigan', 'W', '77', '70'),
#  ('Maryland', 'Sat, Jan 28, 2017', 'Minnesota', 'W', '85', '78'),
#  ('Maryland', 'Wed, Feb 15, 2017', 'Northwestern', 'W', '74', '64'),
#  ('Maryland', 'Sat, Mar 4, 2017', 'Michigan State', 'W', '63', '60'),
#  ('Xavier', 'Wed, Feb 1, 2017', 'Seton Hall', 'W', '72', '70'),
#  ('Xavier', 'Thu, Mar 16, 2017', 'Maryland', 'W', '76', '65'),
#  ('Florida State', 'Tue, Nov 15, 2016', 'Iona', 'W', '99', '78'),
#  ('Florida State', 'Fri, Nov 18, 2016', 'Winthrop', 'W', '100', '86'),
#  ('Florida State', 'Mon, Nov 28, 2016', 'Minnesota', 'W', '75', '67'),
#  ('Florida State', 'Wed, Feb 1, 2017', 'Miami (FL)', 'W', '75', '57'),
#  ('Florida State', 'Sat, Mar 4, 2017', 'Miami (FL)', 'W', '66', '57'),
#  ('Florida State', 'Thu, Mar 9, 2017', 'Virginia Tech', 'W', '74', '68'),
#  ('Florida State', 'Thu, Mar 16, 2017', 'Florida Gulf Coast', 'W', '86', '80'),
#  ("Saint Mary's (CA)", 'Fri, Nov 11, 2016', 'Nevada', 'W', '81', '63'),
#  ("Saint Mary's (CA)", 'Sat, Nov 19, 2016', 'Dayton', 'W', '61', '57'),
#  ('VCU', 'Tue, Nov 29, 2016', 'Princeton', 'W', '81', '70'),
#  ('VCU', 'Sat, Dec 17, 2016', 'Middle Tennessee', 'W', '80', '77'),
#  ('VCU', 'Fri, Jan 27, 2017', 'Dayton', 'W', '73', '68'),
#  ('Arizona', 'Wed, Nov 30, 2016', 'Texas Southern', 'W', '85', '63'),
#  ('Arizona', 'Thu, Mar 16, 2017', 'North Dakota', 'W', '100', '82')]

# %% [raw]
# [('Northwestern', 'Dayton', '2016-12-17', 'W', '67', '64'),
#  ('Northwestern', 'Wisconsin', '2017-02-12', 'W', '66', '59'),
#  ('Northwestern', 'Michigan', '2017-03-01', 'W', '67', '65'),
#  ('Northwestern', 'Maryland', '2017-03-10', 'W', '72', '64')]

# %% [markdown]
# # Making a directed graph

# %%
g = nx.DiGraph()

for (team, opponent, date, score, opp_score) in tournament_results:
    differential = int(score) - int(opp_score)
    if differential > 0:
        if g.has_edge(team,opponent):
            g[team][opponent]['weight'] += differential
        else:
            g.add_edge(team, opponent, weight = abs(differential))
    else:
        print('Negative point differential for: {0}-{1}\n'.format(team,opponent))
        if g.has_edge(team,opponent):
            g[team][opponent]['weight'] += differential
        else:
            g.add_edge(team, opponent, weight = abs(differential))
        
print("There are {0} nodes and {1} edges in the network".format(g.number_of_nodes(), g.number_of_edges()))

nx.write_gexf(g,'tournament_schedule.gexf')
# Out:
# Negative point differential for: Creighton-Marquette
#
# Negative point differential for: Michigan-UCLA
#
# Negative point differential for: Texas Southern-Louisville
#
# Negative point differential for: Winthrop-Florida State
#
# There are 58 nodes and 222 edges in the network

# %%
import networkx as nx

# %%
g = nx.Graph()

# %%
g.add_node('a')

# %%
len(g)
# Out:
# 1

# %%
g.nodes()
# Out:
# ['a']

# %%
g.add_nodes_from(['b','c','d'])

# %%
g.nodes()
# Out:
# ['b', 'c', 'a', 'd']

# %%
len(g)
# Out:
# 4

# %%
g.remove_edge('a','b')

# %%
g.edges()
# Out:
# [('c', 'a'), ('a', 'd')]

# %%
g.add_edges_from([('a','b'),('a','c'),('a','d')])

# %%
g.edges()
# Out:
# [('b', 'a'), ('c', 'a'), ('a', 'd')]

# %%
g.add_edge('d','a')
g.edges()
# Out:
# [('b', 'a'), ('c', 'a'), ('a', 'd')]

# %%
g.edges()
np.array(nx)

# %% [markdown]
# # Making a DiGraph

# %%
dg = nx.DiGraph()

# %%
dg.add_edges_from([('a','b'),('a','c'),('a','d')])

# %%
dg.nodes()
# Out:
# ['b', 'c', 'a', 'd']

# %%
dg.edges()
# Out:
# [('a', 'b'), ('a', 'c'), ('a', 'd')]

# %%
dg.add_edge('c','a')

# %%
dg.edges()
# Out:
# [('c', 'a'), ('a', 'b'), ('a', 'c'), ('a', 'd')]
